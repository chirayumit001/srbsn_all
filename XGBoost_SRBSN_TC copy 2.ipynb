# %%
import pandas as pd

df_2 = pd.read_csv(r'C:\Users\chira\OneDrive\Desktop\srbsn\random-analysis\TC- SRBSN - dataset_for_analysis (10).csv')

# %%
df_2
# Out:
#      Thermal Conductivity(W/mK)  Source Sintering Pressure Oxygen  \
# 0                         102.0  SRBSN2                  1   0.28
# 1                         102.4  SRBSN2                  1   0.28
# 2                         103.4  SRBSN2                  1   0.28
# 3                         101.3  SRBSN2                  1   0.28
# 4                          99.0  SRBSN2                  1   0.28
# ..                          ...     ...                ...    ...
# 116                       155.0  Extra2                  1   0.51
# 117                       154.0  Extra2                  1   0.51
# 118                       151.0  Extra2                  1   0.51
# 119                       143.0  Extra2                  1   0.51
# 120                       136.0  Extra2                  1   0.51
#
#      Particle size(d50 um)  Purity Sintering Add(2:5::Y:M)    Y  Yb    M  ...  \
# 0                      8.5   99.99                     Yes  2.0   0  5.0  ...
# 1                      8.5   99.99                     Yes  2.0   0  5.0  ...
# 2                      8.5   99.99                     Yes  2.0   0  5.0  ...
# 3                      8.5   99.99                     Yes  2.0   0  5.0  ...
# 4                      8.5   99.99                     Yes  2.0   0  5.0  ...
# ..                     ...     ...                     ...  ...  ..  ...  ...
# 116                    2.7   99.99                   1.5:5  1.5   0  5.0  ...
# 117                    2.7   99.99                     2:5  2.0   0  5.0  ...
# 118                    2.7   99.99                   2.5:5  2.5   0  5.0  ...
# 119                    2.7   99.99                     3:5  3.0   0  5.0  ...
# 120                    2.7   99.99                     5:5  5.0   0  5.0  ...
#
#       Eu  C   Al  N2/N2:H2 = 1/0  Nitriding Temperature(degC)  \
# 0    0.0  0  0.0               1                         1400
# 1    0.0  0  0.0               1                         1400
# 2    0.0  0  0.0               1                         1400
# 3    0.0  0  0.0               1                         1400
# 4    0.0  0  0.0               1                         1400
# ..   ... ..  ...             ...                          ...
# 116  0.0  0  0.0               1                         1400
# 117  0.0  0  0.0               1                         1400
# 118  0.0  0  0.0               1                         1400
# 119  0.0  0  0.0               1                         1400
# 120  0.0  0  0.0               1                         1400
#
#      Nitriding Time(h)  Sintering Temperature(degC)  Sintering Time(h)     RD  \
# 0                  4.0                         1850                 60   99.3
# 1                  4.0                         1850                 60  100.0
# 2                  4.0                         1850                 60   99.0
# 3                  4.0                         1850                 60   97.5
# 4                  4.0                         1850                 60   97.6
# ..                 ...                          ...                ...    ...
# 116                4.0                         1900                 24   99.8
# 117                4.0                         1900                 24   99.5
# 118                4.0                         1900                 24   99.2
# 119                4.0                         1900                 24   99.1
# 120                4.0                         1900                 24   98.5
#
#      Verified
# 0         Yes
# 1         Yes
# 2         Yes
# 3         Yes
# 4         Yes
# ..        ...
# 116       NaN
# 117       NaN
# 118       NaN
# 119       NaN
# 120       NaN
#
# [121 rows x 22 columns]

# %%
# df3 = df_2

# %%
# bins = [50,60,70,80,90,100,110,120,130,140,150,160]
# df3['binned'] = pd.cut(df3['Thermal Conductivity(W/mK)'], bins)

# %%
# df3['Thermal Conductivity(W/mK)'].hist(figsize=(5, 5), bins=10, xlabelsize=8, ylabelsize=8)

# %%
df = df_2.drop('Sintering Add(2:5::Y:M)', axis = 1)
df = df.drop('Verified', axis=1)
df = df.drop("RD", axis = 1)
df = df.drop("C", axis=1)
df = df.drop('Source', axis = 1)
df = df.drop("Y", axis=1)
df = df.drop("Yb", axis=1)
df = df.drop("M", axis=1)
df = df.drop("Mn", axis=1)
df = df.drop("L", axis=1)
df = df.drop("Eu", axis=1)
df = df.drop("Al", axis=1)
# df.drop("Oxygen", axis = 1, inplace = True)
df
# Out:
#      Thermal Conductivity(W/mK) Sintering Pressure Oxygen  \
# 0                         102.0                  1   0.28
# 1                         102.4                  1   0.28
# 2                         103.4                  1   0.28
# 3                         101.3                  1   0.28
# 4                          99.0                  1   0.28
# ..                          ...                ...    ...
# 116                       155.0                  1   0.51
# 117                       154.0                  1   0.51
# 118                       151.0                  1   0.51
# 119                       143.0                  1   0.51
# 120                       136.0                  1   0.51
#
#      Particle size(d50 um)  Purity  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99               1
# 1                      8.5   99.99               1
# 2                      8.5   99.99               1
# 3                      8.5   99.99               1
# 4                      8.5   99.99               1
# ..                     ...     ...             ...
# 116                    2.7   99.99               1
# 117                    2.7   99.99               1
# 118                    2.7   99.99               1
# 119                    2.7   99.99               1
# 120                    2.7   99.99               1
#
#      Nitriding Temperature(degC)  Nitriding Time(h)  \
# 0                           1400                4.0
# 1                           1400                4.0
# 2                           1400                4.0
# 3                           1400                4.0
# 4                           1400                4.0
# ..                           ...                ...
# 116                         1400                4.0
# 117                         1400                4.0
# 118                         1400                4.0
# 119                         1400                4.0
# 120                         1400                4.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 0                           1850                 60
# 1                           1850                 60
# 2                           1850                 60
# 3                           1850                 60
# 4                           1850                 60
# ..                           ...                ...
# 116                         1900                 24
# 117                         1900                 24
# 118                         1900                 24
# 119                         1900                 24
# 120                         1900                 24
#
# [121 rows x 10 columns]

# %%
import numpy as np
df['Sintering Pressure'] = np.where((df['Sintering Pressure'] == 'Not mentioned'), 1, df['Sintering Pressure'])
df
# Out:
#      Thermal Conductivity(W/mK) Sintering Pressure Oxygen  \
# 0                         102.0                  1   0.28
# 1                         102.4                  1   0.28
# 2                         103.4                  1   0.28
# 3                         101.3                  1   0.28
# 4                          99.0                  1   0.28
# ..                          ...                ...    ...
# 116                       155.0                  1   0.51
# 117                       154.0                  1   0.51
# 118                       151.0                  1   0.51
# 119                       143.0                  1   0.51
# 120                       136.0                  1   0.51
#
#      Particle size(d50 um)  Purity  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99               1
# 1                      8.5   99.99               1
# 2                      8.5   99.99               1
# 3                      8.5   99.99               1
# 4                      8.5   99.99               1
# ..                     ...     ...             ...
# 116                    2.7   99.99               1
# 117                    2.7   99.99               1
# 118                    2.7   99.99               1
# 119                    2.7   99.99               1
# 120                    2.7   99.99               1
#
#      Nitriding Temperature(degC)  Nitriding Time(h)  \
# 0                           1400                4.0
# 1                           1400                4.0
# 2                           1400                4.0
# 3                           1400                4.0
# 4                           1400                4.0
# ..                           ...                ...
# 116                         1400                4.0
# 117                         1400                4.0
# 118                         1400                4.0
# 119                         1400                4.0
# 120                         1400                4.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 0                           1850                 60
# 1                           1850                 60
# 2                           1850                 60
# 3                           1850                 60
# 4                           1850                 60
# ..                           ...                ...
# 116                         1900                 24
# 117                         1900                 24
# 118                         1900                 24
# 119                         1900                 24
# 120                         1900                 24
#
# [121 rows x 10 columns]

# %%
df['Oxygen'] = np.where((df['Oxygen'] == 'After milling data only'), 0.3, df['Oxygen'])
df
# Out:
#      Thermal Conductivity(W/mK) Sintering Pressure Oxygen  \
# 0                         102.0                  1   0.28
# 1                         102.4                  1   0.28
# 2                         103.4                  1   0.28
# 3                         101.3                  1   0.28
# 4                          99.0                  1   0.28
# ..                          ...                ...    ...
# 116                       155.0                  1   0.51
# 117                       154.0                  1   0.51
# 118                       151.0                  1   0.51
# 119                       143.0                  1   0.51
# 120                       136.0                  1   0.51
#
#      Particle size(d50 um)  Purity  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99               1
# 1                      8.5   99.99               1
# 2                      8.5   99.99               1
# 3                      8.5   99.99               1
# 4                      8.5   99.99               1
# ..                     ...     ...             ...
# 116                    2.7   99.99               1
# 117                    2.7   99.99               1
# 118                    2.7   99.99               1
# 119                    2.7   99.99               1
# 120                    2.7   99.99               1
#
#      Nitriding Temperature(degC)  Nitriding Time(h)  \
# 0                           1400                4.0
# 1                           1400                4.0
# 2                           1400                4.0
# 3                           1400                4.0
# 4                           1400                4.0
# ..                           ...                ...
# 116                         1400                4.0
# 117                         1400                4.0
# 118                         1400                4.0
# 119                         1400                4.0
# 120                         1400                4.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 0                           1850                 60
# 1                           1850                 60
# 2                           1850                 60
# 3                           1850                 60
# 4                           1850                 60
# ..                           ...                ...
# 116                         1900                 24
# 117                         1900                 24
# 118                         1900                 24
# 119                         1900                 24
# 120                         1900                 24
#
# [121 rows x 10 columns]

# %%
np.where(df['Sintering Pressure'] ==0.1)
# Out:
# (array([], dtype=int64),)

# %%
df = df.astype(float)

# %%
df['Oxygen'].fillna(0.3, inplace=True)
df
# Out:
#      Thermal Conductivity(W/mK)  Sintering Pressure  Oxygen  \
# 0                         102.0                 1.0    0.28
# 1                         102.4                 1.0    0.28
# 2                         103.4                 1.0    0.28
# 3                         101.3                 1.0    0.28
# 4                          99.0                 1.0    0.28
# ..                          ...                 ...     ...
# 116                       155.0                 1.0    0.51
# 117                       154.0                 1.0    0.51
# 118                       151.0                 1.0    0.51
# 119                       143.0                 1.0    0.51
# 120                       136.0                 1.0    0.51
#
#      Particle size(d50 um)  Purity  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99             1.0
# 1                      8.5   99.99             1.0
# 2                      8.5   99.99             1.0
# 3                      8.5   99.99             1.0
# 4                      8.5   99.99             1.0
# ..                     ...     ...             ...
# 116                    2.7   99.99             1.0
# 117                    2.7   99.99             1.0
# 118                    2.7   99.99             1.0
# 119                    2.7   99.99             1.0
# 120                    2.7   99.99             1.0
#
#      Nitriding Temperature(degC)  Nitriding Time(h)  \
# 0                         1400.0                4.0
# 1                         1400.0                4.0
# 2                         1400.0                4.0
# 3                         1400.0                4.0
# 4                         1400.0                4.0
# ..                           ...                ...
# 116                       1400.0                4.0
# 117                       1400.0                4.0
# 118                       1400.0                4.0
# 119                       1400.0                4.0
# 120                       1400.0                4.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 0                         1850.0               60.0
# 1                         1850.0               60.0
# 2                         1850.0               60.0
# 3                         1850.0               60.0
# 4                         1850.0               60.0
# ..                           ...                ...
# 116                       1900.0               24.0
# 117                       1900.0               24.0
# 118                       1900.0               24.0
# 119                       1900.0               24.0
# 120                       1900.0               24.0
#
# [121 rows x 10 columns]

# %%
df.isnull().values.sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                              Thermal Conductivity(W/mK)  Sintering Pressure  \
# Thermal Conductivity(W/mK)                     1.000000            0.396265
# Sintering Pressure                             0.396265            1.000000
# Oxygen                                        -0.053544            0.094477
# Particle size(d50 um)                          0.220553            0.245069
# Purity                                         0.381824            0.453723
# N2/N2:H2 = 1/0                                 0.399305           -0.036631
# Nitriding Temperature(degC)                    0.065707            0.314090
# Nitriding Time(h)                             -0.040654           -0.158110
# Sintering Temperature(degC)                    0.279792            0.613942
# Sintering Time(h)                              0.395570            0.159401
#
#                                Oxygen  Particle size(d50 um)    Purity  \
# Thermal Conductivity(W/mK)  -0.053544               0.220553  0.381824
# Sintering Pressure           0.094477               0.245069  0.453723
# Oxygen                       1.000000              -0.164343  0.121418
# Particle size(d50 um)       -0.164343               1.000000  0.454707
# Purity                       0.121418               0.454707  1.000000
# N2/N2:H2 = 1/0               0.025093               0.071151 -0.183489
# Nitriding Temperature(degC)  0.130871               0.232786  0.704686
# Nitriding Time(h)            0.254619               0.034507 -0.334848
# Sintering Temperature(degC)  0.131043              -0.225005  0.053735
# Sintering Time(h)           -0.186209               0.377318  0.185001
#
#                              N2/N2:H2 = 1/0  Nitriding Temperature(degC)  \
# Thermal Conductivity(W/mK)         0.399305                     0.065707
# Sintering Pressure                -0.036631                     0.314090
# Oxygen                             0.025093                     0.130871
# Particle size(d50 um)              0.071151                     0.232786
# Purity                            -0.183489                     0.704686
# N2/N2:H2 = 1/0                     1.000000                    -0.513887
# Nitriding Temperature(degC)       -0.513887                     1.000000
# Nitriding Time(h)                  0.588992                    -0.549137
# Sintering Temperature(degC)        0.053551                     0.054306
# Sintering Time(h)                  0.271765                     0.000338
#
#                              Nitriding Time(h)  Sintering Temperature(degC)  \
# Thermal Conductivity(W/mK)           -0.040654                     0.279792
# Sintering Pressure                   -0.158110                     0.613942
# Oxygen                                0.254619                     0.131043
# Particle size(d50 um)                 0.034507                    -0.225005
# Purity                               -0.334848                     0.053735
# N2/N2:H2 = 1/0                        0.588992                     0.053551
# Nitriding Temperature(degC)          -0.549137                     0.054306
# Nitriding Time(h)                     1.000000                    -0.006360
# Sintering Temperature(degC)          -0.006360                     1.000000
# Sintering Time(h)                    -0.098405                    -0.104849
#
#                              Sintering Time(h)
# Thermal Conductivity(W/mK)            0.395570
# Sintering Pressure                    0.159401
# Oxygen                               -0.186209
# Particle size(d50 um)                 0.377318
# Purity                                0.185001
# N2/N2:H2 = 1/0                        0.271765
# Nitriding Temperature(degC)           0.000338
# Nitriding Time(h)                    -0.098405
# Sintering Temperature(degC)          -0.104849
# Sintering Time(h)                     1.000000

# %%
normalized_df=(df-df.mean())/df.std()
tc_std = df['Thermal Conductivity(W/mK)'].std()
tc_mean = df['Thermal Conductivity(W/mK)'].mean()

# %%
# normalized_df['Sintering Pressure'].head(50)
(normalized_df['Thermal Conductivity(W/mK)']*tc_std)+tc_mean
# Out:
# 0      102.0
# 1      102.4
# 2      103.4
# 3      101.3
# 4       99.0
#        ...
# 116    155.0
# 117    154.0
# 118    151.0
# 119    143.0
# 120    136.0
# Name: Thermal Conductivity(W/mK), Length: 121, dtype: float64

# %%
import seaborn as sns
# %matplotlib inline

# load the Auto dataset
auto_df = df

# calculate the correlation matrix on the numeric columns
corr = auto_df.select_dtypes('number').corr()

# plot the heatmap
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
correlation_plot = df.corr()['Thermal Conductivity(W/mK)'][1:].plot(kind='barh')
correlation_plot
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt


plt.scatter(df['Thermal Conductivity(W/mK)'], df['Particle size(d50 um)'])

# %%
data = df
fig, ax = plt.subplots()
data['Thermal Conductivity(W/mK)'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <Axes: xlabel='Thermal Conductivity(W/mK)'>

# %%
X = df.drop('Thermal Conductivity(W/mK)',axis=1)
y = df['Thermal Conductivity(W/mK)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

# %%
X_test
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)   Purity  \
# 44                  0.9    1.09                  1.680  99.9900
# 47                  0.1    0.30                  1.000  99.0000
# 4                   1.0    0.28                  8.500  99.9900
# 55                  1.0    0.30                  1.000  99.0000
# 26                  0.9    0.30                  1.676  99.9990
# 64                  0.9    0.30                  1.000  99.9000
# 73                  1.0    0.46                  4.350  99.9900
# 10                  1.0    0.28                  2.700  99.9900
# 40                  1.0    0.30                  7.000  99.9100
# 108                 1.0    0.51                  2.700  99.9900
# 18                  1.0    0.30                  7.000  99.9100
# 62                  0.9    0.30                  1.000  99.9000
# 11                  1.0    0.28                  2.700  99.9900
# 36                  1.0    0.82                  1.400  99.9900
# 90                  1.0    0.51                  2.700  99.9900
# 118                 1.0    0.51                  2.700  99.9900
# 110                 1.0    0.51                  2.700  99.9900
# 0                   1.0    0.28                  8.500  99.9900
# 89                  1.0    0.51                  2.700  99.9900
# 104                 1.0    0.51                  2.700  99.9900
# 65                  0.9    0.30                  1.000  99.9000
# 45                  0.9    1.09                  1.680  99.9900
# 31                  0.1    0.30                  1.000  99.0000
# 70                  1.0    0.91                  4.600  99.9999
# 42                  0.9    1.09                  1.680  99.9900
# 12                  0.9    1.58                  5.270  99.9000
# 15                  1.0    1.28                  0.700  99.7000
# 115                 1.0    0.51                  2.700  99.9900
# 76                  1.0    0.46                  4.350  99.9900
# 98                  1.0    0.51                  2.700  99.9900
# 24                  1.0    0.28                  5.000  99.9900
# 78                  1.0    0.46                  4.350  99.9900
# 22                  1.0    0.28                  5.000  99.9900
# 97                  1.0    0.51                  2.700  99.9900
# 56                  1.0    0.30                  1.000  99.0000
# 111                 1.0    0.51                  2.700  99.9900
# 30                  1.0    0.30                  1.000  99.0000
#
#      N2/N2:H2 = 1/0  Nitriding Temperature(degC)  Nitriding Time(h)  \
# 44              1.0                       1400.0                8.0
# 47              1.0                       1350.0                6.0
# 4               1.0                       1400.0                4.0
# 55              1.0                       1350.0                6.0
# 26              1.0                       1400.0                8.0
# 64              0.0                       1450.0                0.0
# 73              0.0                       1400.0                4.0
# 10              1.0                       1400.0                8.0
# 40              1.0                       1400.0                8.0
# 108             1.0                       1400.0                4.0
# 18              1.0                       1400.0                8.0
# 62              0.0                       1450.0                0.0
# 11              1.0                       1400.0                8.0
# 36              1.0                       1400.0                8.0
# 90              1.0                       1400.0                4.0
# 118             1.0                       1400.0                4.0
# 110             1.0                       1400.0                4.0
# 0               1.0                       1400.0                4.0
# 89              1.0                       1400.0                4.0
# 104             1.0                       1400.0                4.0
# 65              0.0                       1450.0                0.0
# 45              1.0                       1400.0                8.0
# 31              1.0                       1350.0                8.0
# 70              0.0                       1450.0                2.5
# 42              1.0                       1400.0                8.0
# 12              1.0                       1400.0                8.0
# 15              1.0                       1350.0                8.0
# 115             1.0                       1400.0                4.0
# 76              0.0                       1400.0                4.0
# 98              1.0                       1400.0                4.0
# 24              1.0                       1400.0                4.0
# 78              0.0                       1400.0                4.0
# 22              1.0                       1400.0                4.0
# 97              1.0                       1400.0                4.0
# 56              1.0                       1350.0                6.0
# 111             1.0                       1400.0                4.0
# 30              1.0                       1350.0                8.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 44                        1900.0                6.0
# 47                        1800.0                6.0
# 4                         1850.0               60.0
# 55                        1950.0                6.0
# 26                        1900.0                6.0
# 64                        1900.0                6.0
# 73                        1900.0                4.0
# 10                        1900.0               12.0
# 40                        1900.0               12.0
# 108                       1900.0                6.0
# 18                        1900.0                6.0
# 62                        1900.0                6.0
# 11                        1900.0               24.0
# 36                        1900.0               12.0
# 90                        1900.0                6.0
# 118                       1900.0               24.0
# 110                       1900.0                6.0
# 0                         1850.0               60.0
# 89                        1900.0                6.0
# 104                       1900.0               24.0
# 65                        1900.0                6.0
# 45                        1900.0                6.0
# 31                        1800.0                6.0
# 70                        1900.0                3.0
# 42                        1900.0                6.0
# 12                        1900.0                6.0
# 15                        1900.0               12.0
# 115                       1900.0               24.0
# 76                        1850.0                4.0
# 98                        1900.0               24.0
# 24                        1900.0               24.0
# 78                        1850.0                4.0
# 22                        1900.0                6.0
# 97                        1900.0               24.0
# 56                        1950.0                6.0
# 111                       1900.0                6.0
# 30                        1900.0                6.0

# %%
pd.DataFrame(X.iloc[45]).T
# Out:
#     Sintering Pressure  Oxygen  Particle size(d50 um)  Purity  N2/N2:H2 = 1/0  \
# 45                 0.9    1.09                   1.68   99.99             1.0
#
#     Nitriding Temperature(degC)  Nitriding Time(h)  \
# 45                       1400.0                8.0
#
#     Sintering Temperature(degC)  Sintering Time(h)
# 45                       1900.0                6.0

# %%
# t = X_test[X_test['Particle size(d50 um)']==5.270]
t = pd.DataFrame(X.iloc[12]).T
u = pd.DataFrame(X.iloc[42]).T
v = pd.DataFrame(X.iloc[44]).T
w = pd.DataFrame(X.iloc[45]).T
X_train = pd.concat([X_train, t, u, v, w])
X_train
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)  Purity  \
# 53                  1.0    0.30                   1.00   99.00
# 119                 1.0    0.51                   2.70   99.99
# 9                   1.0    0.28                   2.70   99.99
# 33                  1.0    0.47                   9.90   99.99
# 25                  1.0    0.28                   5.00   99.99
# ..                  ...     ...                    ...     ...
# 102                 1.0    0.51                   2.70   99.99
# 12                  0.9    1.58                   5.27   99.90
# 42                  0.9    1.09                   1.68   99.99
# 44                  0.9    1.09                   1.68   99.99
# 45                  0.9    1.09                   1.68   99.99
#
#      N2/N2:H2 = 1/0  Nitriding Temperature(degC)  Nitriding Time(h)  \
# 53              1.0                       1350.0                6.0
# 119             1.0                       1400.0                4.0
# 9               1.0                       1400.0                8.0
# 33              1.0                       1400.0                8.0
# 25              1.0                       1400.0                4.0
# ..              ...                          ...                ...
# 102             1.0                       1400.0                4.0
# 12              1.0                       1400.0                8.0
# 42              1.0                       1400.0                8.0
# 44              1.0                       1400.0                8.0
# 45              1.0                       1400.0                8.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 53                        1950.0                6.0
# 119                       1900.0               24.0
# 9                         1900.0                6.0
# 33                        1900.0               12.0
# 25                        1900.0               48.0
# ..                           ...                ...
# 102                       1900.0               24.0
# 12                        1900.0                6.0
# 42                        1900.0                6.0
# 44                        1900.0                6.0
# 45                        1900.0                6.0
#
# [88 rows x 9 columns]

# %%
X_test.drop(12, inplace=True)
X_test.drop(42, inplace=True)
X_test.drop(44, inplace=True)
X_test.drop(45, inplace=True)

# %%
df['Thermal Conductivity(W/mK)'][12]
# Out:
# 88.8

# %%
y_train[12]=df['Thermal Conductivity(W/mK)'][12]
y_train[42]=df['Thermal Conductivity(W/mK)'][42]
y_train[44]=df['Thermal Conductivity(W/mK)'][44]
y_train[45]=df['Thermal Conductivity(W/mK)'][45]
y_train
# Out:
# 53      85.0
# 119    143.0
# 9      105.0
# 33     102.0
# 25     142.0
#        ...
# 102    148.0
# 12      88.8
# 42      91.9
# 44      74.1
# 45      66.2
# Name: Thermal Conductivity(W/mK), Length: 88, dtype: float64

# %%
y_train = y_train.drop(80)
y_train = y_train.drop(81)
X_train.drop(80, inplace=True)
X_train.drop(81, inplace=True)

# %%
y_test = y_test.drop(12)
y_test = y_test.drop(42)
y_test = y_test.drop(44)
y_test = y_test.drop(45)

# %%
df.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<Axes: title={'center': 'Thermal Conductivity(W/mK)'}>,
#         <Axes: title={'center': 'Sintering Pressure'}>,
#         <Axes: title={'center': 'Oxygen'}>],
#        [<Axes: title={'center': 'Particle size(d50 um)'}>,
#         <Axes: title={'center': 'Purity'}>,
#         <Axes: title={'center': 'N2/N2:H2 = 1/0'}>],
#        [<Axes: title={'center': 'Nitriding Temperature(degC)'}>,
#         <Axes: title={'center': 'Nitriding Time(h)'}>,
#         <Axes: title={'center': 'Sintering Temperature(degC)'}>],
#        [<Axes: title={'center': 'Sintering Time(h)'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
df['Thermal Conductivity(W/mK)'].hist(figsize=(5, 5), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# <Axes: >

# %%
y_train
# Out:
# 53      85.0
# 119    143.0
# 9      105.0
# 33     102.0
# 25     142.0
#        ...
# 102    148.0
# 12      88.8
# 42      91.9
# 44      74.1
# 45      66.2
# Name: Thermal Conductivity(W/mK), Length: 86, dtype: float64

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

# my_model = XGBRegressor(max_depth = 2)
# # Add silent=True to avoid printing out updates with each cycle
# my_model.fit(X_train, y_train, verbose=True)

# Define the hyperparameter grid
# param_grid = {
        # 'min_child_weight': [1, 5, 10],
        # 'gamma': [0.5, 1, 1.5, 2, 5],
        # 'subsample': [0.6, 0.8, 1.0],
        # 'colsample_bytree': [0.6, 0.8, 1.0],
        # 'max_depth': [3, 4, 5]
        # }
param_grid = {'gamma': [0.5, 1, 1.5, 2, 5]}
# Create the XGBoost model object
xgb_model = XGBRegressor() 

# Create the GridSearchCV object
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')

# Fit the GridSearchCV object to the training data
results = grid_search.fit(X_train, y_train)
results
# Print the best set of hyperparameters and the corresponding score
print("Best set of hyperparameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# Best set of hyperparameters:  {'gamma': 5}
# Best score:  0.564465323271436

# %%
from sklearn.model_selection import StratifiedKFold
# XGBoost on Otto dataset, Tune max_depth
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot

max_depth = [3,4,5]
param_grid = dict(max_depth=max_depth)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(xgb_model, param_grid, scoring="r2", n_jobs=-1, verbose=1)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
 print("%f (%f) with: %r" % (mean, stdev, param))
# plot

plt.figure()
pyplot.errorbar(max_depth, means, yerr=stds)
pyplot.title("XGBoost max_depth vs R2")
pyplot.xlabel('max_depth')
pyplot.ylabel('R2')
pyplot.savefig('max_depth.tif', dpi =80)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best: 0.559209 using {'max_depth': 4}
# 0.556746 (0.166079) with: {'max_depth': 3}
# 0.559209 (0.169389) with: {'max_depth': 4}
# 0.540007 (0.146854) with: {'max_depth': 5}

# %%
from sklearn.model_selection import StratifiedKFold
# XGBoost on Otto dataset, Tune max_depth
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot

colsample_bytree = [0.6, 0.8, 1.0]
param_grid = dict(colsample_bytree=colsample_bytree)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(xgb_model, param_grid, scoring="r2", n_jobs=-1, verbose=1)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
 print("%f (%f) with: %r" % (mean, stdev, param))
# plot

plt.figure()
pyplot.errorbar(colsample_bytree, means, yerr=stds)
pyplot.title("XGBoost colsample_bytree vs R2")
pyplot.xlabel('colsample_bytree')
pyplot.ylabel('R2')
pyplot.savefig('colsample_bytree.png')
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best: 0.565534 using {'colsample_bytree': 0.8}
# 0.564475 (0.185314) with: {'colsample_bytree': 0.6}
# 0.565534 (0.181374) with: {'colsample_bytree': 0.8}
# 0.536511 (0.143430) with: {'colsample_bytree': 1.0}

# %%
from sklearn.model_selection import StratifiedKFold
# XGBoost on Otto dataset, Tune max_depth
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot

subsample = [0.6, 0.8, 1.0]
param_grid = dict(subsample=subsample)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(xgb_model, param_grid, scoring="r2", n_jobs=-1, verbose=1)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
 print("%f (%f) with: %r" % (mean, stdev, param))
# plot

plt.figure()
pyplot.errorbar(subsample, means, yerr=stds)
pyplot.title("XGBoost subsample vs R2")
pyplot.xlabel('subsample')
pyplot.ylabel('R2')
pyplot.savefig('subsample.png')
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best: 0.543136 using {'subsample': 0.8}
# 0.529199 (0.133243) with: {'subsample': 0.6}
# 0.543136 (0.158138) with: {'subsample': 0.8}
# 0.536511 (0.143430) with: {'subsample': 1.0}

# %%
from sklearn.model_selection import StratifiedKFold
# XGBoost on Otto dataset, Tune max_depth
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot

gamma = [0.5, 1, 1.5, 2, 5]
param_grid = dict(gamma=gamma)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(xgb_model, param_grid, scoring="r2", n_jobs=-1, verbose=1)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
 print("%f (%f) with: %r" % (mean, stdev, param))
# plot

plt.figure()
pyplot.errorbar(gamma, means, yerr=stds)
pyplot.title("XGBoost gamma vs R2")
pyplot.xlabel('gamma')
pyplot.ylabel('R2')
pyplot.savefig('gamma.png')
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Best: 0.564465 using {'gamma': 5}
# 0.543215 (0.135872) with: {'gamma': 0.5}
# 0.546900 (0.133263) with: {'gamma': 1}
# 0.549483 (0.130256) with: {'gamma': 1.5}
# 0.551906 (0.129323) with: {'gamma': 2}
# 0.564465 (0.127772) with: {'gamma': 5}

# %%
from sklearn.model_selection import StratifiedKFold
# XGBoost on Otto dataset, Tune max_depth
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot

min_child_weight = [1, 5, 10]
param_grid = dict(min_child_weight=min_child_weight)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(xgb_model, param_grid, scoring="r2", n_jobs=-1, verbose=1)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
 print("%f (%f) with: %r" % (mean, stdev, param))
# plot

plt.figure()
pyplot.errorbar(min_child_weight, means, yerr=stds)
pyplot.title("XGBoost min_child_weight vs R2")
pyplot.xlabel('min_child_weight')
pyplot.ylabel('R2')
pyplot.savefig('min_child_weight.png')
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best: 0.567808 using {'min_child_weight': 10}
# 0.536511 (0.143430) with: {'min_child_weight': 1}
# 0.531852 (0.149219) with: {'min_child_weight': 5}
# 0.567808 (0.167986) with: {'min_child_weight': 10}

# %%
my_model = XGBRegressor(colsample_bytree = 0.6, gamma = 2, max_depth = 5, min_child_weight = 1, subsample = 0.6)
# Add silent=True to avoid printing out updates with each cycle
my_model.fit(X_train, y_train, verbose=True)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=2, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# def get_xgb_imp(xgb, feat_names):
#     from numpy import array
#     imp_vals = xgb.booster().get_fscore()
#     imp_dict = {feat_names[i]:float(imp_vals.get('f'+str(i),0.)) for i in range(len(feat_names))}
#     total = array(imp_dict.values()).sum()
#     return {k:v/total for k,v in imp_dict.items()}

# feat_names = [['Sintering Pressure', 'Oxygen', 'Particle size(d50 um)', 'Purity', 'Y',
#        'Yb', 'M', 'Mn', 'L', 'Eu', 'Al', 'N2/N2:H2 = 1/0',
#        'Nitriding Temperature(degC)', 'Nitriding Time(h)',
#        'Sintering Temperature(degC)', 'Sintering Time(h)']]
# get_xgb_imp(my_model,feat_names)

# %%
# make predictions
predictions = my_model.predict(X_test)

# from sklearn.metrics import mean_absolute_error
# print("Mean Absolute Error : " + str(mean_absolute_error(predictions, X_test)))
len(predictions)
# Out:
# 33

# %%
# # grid search
# model = XGBClassifier()
# n_estimators = range(50, 400, 50)
# param_grid = dict(n_estimators=n_estimators)
# kfold = StratifiedKFold(n_splits scoring="neg_log_loss", n_jobs=-1, cv=kfold)
# result = grid_search.fit(X, label_encoded_y)

# %%
print(results)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'gamma': [0.5, 1, 1.5, 2, 5]}, scoring='r2')

# %%
# # XGBoost on Otto dataset, Tune n_estimators
# from pandas import read_csv
# from xgboost import XGBClassifier
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import StratifiedKFold
# from sklearn.preprocessing import LabelEncoder
# import matplotlib
# matplotlib.use('Agg')
# from matplotlib import pyplot

# # summarize results
# print("Best: %f using %s" % (results.best_score_, results.best_params_))


# print(mean , 'djhgffghj')

# %%
test_df = pd.DataFrame(y_test)
test_df['Actual'] = y_test[0:]
test_df.drop("Thermal Conductivity(W/mK)", axis = 1, inplace=True)
test_df
# Out:
#      Actual
# 47    61.00
# 4     99.00
# 55    94.00
# 26    82.00
# 64    71.00
# 73    97.70
# 10   115.00
# 40   121.00
# 108  121.00
# 18   111.00
# 62    75.00
# 11   133.00
# 36   119.00
# 90   124.00
# 118  151.00
# 110  128.00
# 0    102.00
# 89   123.00
# 104  142.00
# 65    68.50
# 31    66.70
# 70    82.56
# 15   112.00
# 115  145.00
# 76    94.00
# 98   154.00
# 24   133.00
# 78    84.00
# 22   105.00
# 97   149.00
# 56    84.00
# 111  122.00
# 30    83.00

# %%
test_df['Predictions'] = predictions
test_df['Predictions - Actual/actual'] = ((test_df['Predictions']-test_df['Actual'])/test_df['Actual'])*100
test_df
# Out:
#      Actual  Predictions  Predictions - Actual/actual
# 47    61.00    65.115158                     6.746161
# 4     99.00   103.576218                     4.622442
# 55    94.00    86.633743                    -7.836443
# 26    82.00    76.522034                    -6.680447
# 64    71.00    74.443542                     4.850060
# 73    97.70    85.896263                   -12.081614
# 10   115.00   103.122337                   -10.328402
# 40   121.00   120.224785                    -0.640674
# 108  121.00   107.902977                   -10.823986
# 18   111.00   108.716141                    -2.057531
# 62    75.00    74.443542                    -0.741943
# 11   133.00   134.267181                     0.952768
# 36   119.00    88.405525                   -25.709643
# 90   124.00   107.902977                   -12.981470
# 118  151.00   138.518677                    -8.265777
# 110  128.00   107.902977                   -15.700799
# 0    102.00   103.576218                     1.545311
# 89   123.00   107.902977                   -12.274002
# 104  142.00   138.518677                    -2.451636
# 65    68.50    74.443542                     8.676704
# 31    66.70    72.955460                     9.378500
# 70    82.56    87.831390                     6.384921
# 15   112.00   108.428940                    -3.188447
# 115  145.00   138.518677                    -4.469878
# 76    94.00    69.303352                   -26.273029
# 98   154.00   138.518677                   -10.052807
# 24   133.00   136.809311                     2.864144
# 78    84.00    69.303352                   -17.496009
# 22   105.00   107.543381                     2.422267
# 97   149.00   138.518677                    -7.034445
# 56    84.00    86.633743                     3.135409
# 111  122.00   107.902977                   -11.554937
# 30    83.00    75.411125                    -9.143223

# %%
(predictions*tc_std)+tc_mean
# Out:
# array([1778.7286, 2768.424 , 2332.4536, 2072.255 , 2018.7704, 2313.4763,
#        2756.7446, 3196.8318, 2879.762 , 2900.6868, 2018.7704, 3558.1763,
#        2378.0457, 2879.762 , 3667.5776, 2879.762 , 2768.424 , 2879.762 ,
#        3667.5776, 2018.7704, 1980.4784, 2363.272 , 2893.2964, 3667.5776,
#        1886.501 , 3667.5776, 3623.5916, 1886.501 , 2870.5088, 3667.5776,
#        2332.4536, 2879.762 , 2043.6686], dtype=float32)

# %%
ytest2 = y_test
pred2 = predictions
v = ytest2-pred2
v = pd.DataFrame(v)
v = v.drop(18)

# %%
import numpy as np
import tensorflow as tf
import math
# Out:
# WARNING:tensorflow:From c:\Users\chira\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
MS = np.square(v).mean()
rs = math.sqrt(MS)
rs
# Out:
# C:\Users\chira\AppData\Local\Temp\ipykernel_7076\195823076.py:2: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rs = math.sqrt(MS)
# 11.459816043269734

# %%
X_test
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)   Purity  \
# 47                  0.1    0.30                  1.000  99.0000
# 4                   1.0    0.28                  8.500  99.9900
# 55                  1.0    0.30                  1.000  99.0000
# 26                  0.9    0.30                  1.676  99.9990
# 64                  0.9    0.30                  1.000  99.9000
# 73                  1.0    0.46                  4.350  99.9900
# 10                  1.0    0.28                  2.700  99.9900
# 40                  1.0    0.30                  7.000  99.9100
# 108                 1.0    0.51                  2.700  99.9900
# 18                  1.0    0.30                  7.000  99.9100
# 62                  0.9    0.30                  1.000  99.9000
# 11                  1.0    0.28                  2.700  99.9900
# 36                  1.0    0.82                  1.400  99.9900
# 90                  1.0    0.51                  2.700  99.9900
# 118                 1.0    0.51                  2.700  99.9900
# 110                 1.0    0.51                  2.700  99.9900
# 0                   1.0    0.28                  8.500  99.9900
# 89                  1.0    0.51                  2.700  99.9900
# 104                 1.0    0.51                  2.700  99.9900
# 65                  0.9    0.30                  1.000  99.9000
# 31                  0.1    0.30                  1.000  99.0000
# 70                  1.0    0.91                  4.600  99.9999
# 15                  1.0    1.28                  0.700  99.7000
# 115                 1.0    0.51                  2.700  99.9900
# 76                  1.0    0.46                  4.350  99.9900
# 98                  1.0    0.51                  2.700  99.9900
# 24                  1.0    0.28                  5.000  99.9900
# 78                  1.0    0.46                  4.350  99.9900
# 22                  1.0    0.28                  5.000  99.9900
# 97                  1.0    0.51                  2.700  99.9900
# 56                  1.0    0.30                  1.000  99.0000
# 111                 1.0    0.51                  2.700  99.9900
# 30                  1.0    0.30                  1.000  99.0000
#
#      N2/N2:H2 = 1/0  Nitriding Temperature(degC)  Nitriding Time(h)  \
# 47              1.0                       1350.0                6.0
# 4               1.0                       1400.0                4.0
# 55              1.0                       1350.0                6.0
# 26              1.0                       1400.0                8.0
# 64              0.0                       1450.0                0.0
# 73              0.0                       1400.0                4.0
# 10              1.0                       1400.0                8.0
# 40              1.0                       1400.0                8.0
# 108             1.0                       1400.0                4.0
# 18              1.0                       1400.0                8.0
# 62              0.0                       1450.0                0.0
# 11              1.0                       1400.0                8.0
# 36              1.0                       1400.0                8.0
# 90              1.0                       1400.0                4.0
# 118             1.0                       1400.0                4.0
# 110             1.0                       1400.0                4.0
# 0               1.0                       1400.0                4.0
# 89              1.0                       1400.0                4.0
# 104             1.0                       1400.0                4.0
# 65              0.0                       1450.0                0.0
# 31              1.0                       1350.0                8.0
# 70              0.0                       1450.0                2.5
# 15              1.0                       1350.0                8.0
# 115             1.0                       1400.0                4.0
# 76              0.0                       1400.0                4.0
# 98              1.0                       1400.0                4.0
# 24              1.0                       1400.0                4.0
# 78              0.0                       1400.0                4.0
# 22              1.0                       1400.0                4.0
# 97              1.0                       1400.0                4.0
# 56              1.0                       1350.0                6.0
# 111             1.0                       1400.0                4.0
# 30              1.0                       1350.0                8.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 47                        1800.0                6.0
# 4                         1850.0               60.0
# 55                        1950.0                6.0
# 26                        1900.0                6.0
# 64                        1900.0                6.0
# 73                        1900.0                4.0
# 10                        1900.0               12.0
# 40                        1900.0               12.0
# 108                       1900.0                6.0
# 18                        1900.0                6.0
# 62                        1900.0                6.0
# 11                        1900.0               24.0
# 36                        1900.0               12.0
# 90                        1900.0                6.0
# 118                       1900.0               24.0
# 110                       1900.0                6.0
# 0                         1850.0               60.0
# 89                        1900.0                6.0
# 104                       1900.0               24.0
# 65                        1900.0                6.0
# 31                        1800.0                6.0
# 70                        1900.0                3.0
# 15                        1900.0               12.0
# 115                       1900.0               24.0
# 76                        1850.0                4.0
# 98                        1900.0               24.0
# 24                        1900.0               24.0
# 78                        1850.0                4.0
# 22                        1900.0                6.0
# 97                        1900.0               24.0
# 56                        1950.0                6.0
# 111                       1900.0                6.0
# 30                        1900.0                6.0

# %%
columns = X_test.columns
columns
# Out:
# Index(['Sintering Pressure', 'Oxygen', 'Particle size(d50 um)', 'Purity',
#        'N2/N2:H2 = 1/0', 'Nitriding Temperature(degC)', 'Nitriding Time(h)',
#        'Sintering Temperature(degC)', 'Sintering Time(h)'],
#       dtype='object')

# %%
(y_test)
# Out:
# 47      61.00
# 4       99.00
# 55      94.00
# 26      82.00
# 64      71.00
# 73      97.70
# 10     115.00
# 40     121.00
# 108    121.00
# 18     111.00
# 62      75.00
# 11     133.00
# 36     119.00
# 90     124.00
# 118    151.00
# 110    128.00
# 0      102.00
# 89     123.00
# 104    142.00
# 65      68.50
# 31      66.70
# 70      82.56
# 15     112.00
# 115    145.00
# 76      94.00
# 98     154.00
# 24     133.00
# 78      84.00
# 22     105.00
# 97     149.00
# 56      84.00
# 111    122.00
# 30      83.00
# Name: Thermal Conductivity(W/mK), dtype: float64

# %%
import numpy as np
import math

MSE = np.square(np.subtract(predictions, y_test)).mean()
rsme = math.sqrt(MSE)
rsme
# Out:
# 11.291847814196068

# %%
peri = my_model.predict(X_train)
# (peri*tc_std)+tc_mean
peri
# Out:
# array([ 86.63374 , 138.51868 , 106.2754  , 102.53927 , 143.20404 ,
#         88.37933 ,  89.535645, 138.51868 , 110.94581 , 103.57622 ,
#        107.90298 ,  74.44354 , 108.71614 ,  65.11516 , 102.53927 ,
#        113.01815 ,  74.44354 , 102.53927 , 138.51868 ,  76.653656,
#         71.04665 ,  69.30335 ,  74.44354 , 107.70403 ,  89.535645,
#        120.224785, 138.51868 , 138.51868 ,  98.97558 ,  93.67676 ,
#        110.94581 , 103.57622 , 120.224785,  88.405525, 107.90298 ,
#         72.95546 ,  85.89626 , 107.90298 , 107.90298 ,  86.63374 ,
#         79.82959 ,  71.04665 ,  74.44354 , 138.51868 ,  85.89626 ,
#        107.90298 , 133.49591 , 105.392494,  65.11516 , 107.90298 ,
#        107.90298 , 105.392494,  85.89626 ,  75.411125, 138.51868 ,
#        105.392494,  74.44354 , 138.51868 ,  88.405525,  72.95546 ,
#        107.90298 , 103.57622 ,  79.82959 , 101.46973 , 103.57622 ,
#        117.66249 , 138.51868 , 138.51868 , 107.90298 , 107.90298 ,
#         69.30335 , 112.00632 , 106.092255, 138.51868 , 133.49591 ,
#        105.392494,  63.36693 , 107.90298 , 102.822624, 107.90298 ,
#         79.82959 , 138.51868 ,  93.67676 ,  71.04665 ,  71.04665 ,
#         71.04665 ], dtype=float32)

# %%
len(peri)
# Out:
# 86

# %%
MSE2 = np.square(np.subtract(peri, y_train)).mean()
rsme2 = math.sqrt(MSE2)

# %%
rsme2
# Out:
# 12.960979211873784

# %%
f = pd.DataFrame(y_train)
f
# Out:
#      Thermal Conductivity(W/mK)
# 53                         85.0
# 119                       143.0
# 9                         105.0
# 33                        102.0
# 25                        142.0
# ..                          ...
# 102                       148.0
# 12                         88.8
# 42                         91.9
# 44                         74.1
# 45                         66.2
#
# [86 rows x 1 columns]

# %%
f['Predictions'] = peri
f
# Out:
#      Thermal Conductivity(W/mK)  Predictions
# 53                         85.0    86.633743
# 119                       143.0   138.518677
# 9                         105.0   106.275398
# 33                        102.0   102.539268
# 25                        142.0   143.204041
# ..                          ...          ...
# 102                       148.0   138.518677
# 12                         88.8    93.676758
# 42                         91.9    71.046654
# 44                         74.1    71.046654
# 45                         66.2    71.046654
#
# [86 rows x 2 columns]

# %%
for_checking = pd.DataFrame(y_train)
for_checking
# Out:
#      Thermal Conductivity(W/mK)
# 53                         85.0
# 119                       143.0
# 9                         105.0
# 33                        102.0
# 25                        142.0
# ..                          ...
# 102                       148.0
# 12                         88.8
# 42                         91.9
# 44                         74.1
# 45                         66.2
#
# [86 rows x 1 columns]

# %%
for_checking['Predicted by model'] = peri
for_checking
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model
# 53                         85.0           86.633743
# 119                       143.0          138.518677
# 9                         105.0          106.275398
# 33                        102.0          102.539268
# 25                        142.0          143.204041
# ..                          ...                 ...
# 102                       148.0          138.518677
# 12                         88.8           93.676758
# 42                         91.9           71.046654
# 44                         74.1           71.046654
# 45                         66.2           71.046654
#
# [86 rows x 2 columns]

# %%
import scipy

slope_train, intercept_train, r_value_train, p_value_train, std_err_train = scipy.stats.linregress(for_checking['Thermal Conductivity(W/mK)'], for_checking['Predicted by model'])
r_value_train**2
# Out:
# 0.7391339294412401

# %%
r_value_train
# Out:
# 0.8597289860422528

# %%
f.to_csv("Origin_train_data.csv")

# %%
f.plot.scatter(x='Predictions', y='Thermal Conductivity(W/mK)', title= "Represents training set deviation in values")
plt.text(.01, .99, 'R² = {}'.format(r_value_train**2), ha='left', va='top', transform=ax.transAxes)
# Out:
# Text(0.01, 0.99, 'R² = 0.7391339294412401')

# %%
predictions
# Out:
# array([ 65.11516 , 103.57622 ,  86.63374 ,  76.52203 ,  74.44354 ,
#         85.89626 , 103.12234 , 120.224785, 107.90298 , 108.71614 ,
#         74.44354 , 134.26718 ,  88.405525, 107.90298 , 138.51868 ,
#        107.90298 , 103.57622 , 107.90298 , 138.51868 ,  74.44354 ,
#         72.95546 ,  87.83139 , 108.42894 , 138.51868 ,  69.30335 ,
#        138.51868 , 136.80931 ,  69.30335 , 107.54338 , 138.51868 ,
#         86.63374 , 107.90298 ,  75.411125], dtype=float32)

# %%
(((y_test-predictions)/y_test).mean())*100
# Out:
# 5.0366198878205415

# %%
y_test-predictions
# Out:
# 47     -4.003853
# 4      -4.751610
# 55      6.840973
# 26      2.372101
# 64     -2.478058
# 73     -0.007291
# 10      1.828476
# 40      0.820671
# 108    -1.775635
# 18      1.050568
# 62      1.521942
# 11     -0.952118
# 36     32.151871
# 90     -2.780502
# 118    -2.114853
# 110     4.786377
# 0      -1.751610
# 89     -1.209106
# 104     8.696793
# 65     -7.829353
# 31     -2.720052
# 70      2.175692
# 15      3.096275
# 115    -5.467438
# 76      6.624474
# 98      1.009415
# 24     -5.300339
# 78     -3.375526
# 22     -5.373528
# 97      4.256134
# 56      6.187874
# 111    10.025719
# 30      4.860558
# Name: Thermal Conductivity(W/mK), dtype: float64

# %%
for_checking['Percentage Error'] = ((for_checking['Predicted by model']-for_checking['Thermal Conductivity(W/mK)'])/for_checking['Thermal Conductivity(W/mK)'])*100

# %%
for_checking.sort_index()
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error
# 1                         102.4          103.751610          1.319931
# 2                         103.4          103.751610          0.340048
# 3                         101.3          103.751610          2.420148
# 5                         108.4          103.751610         -4.288183
# 6                          66.7           69.420052          4.078038
# ..                          ...                 ...               ...
# 114                       126.0          124.987167         -0.803835
# 116                       155.0          155.203842          0.131511
# 117                       154.0          153.114853         -0.574771
# 119                       143.0          143.014709          0.010286
# 120                       136.0          134.556458         -1.061428
#
# [86 rows x 3 columns]

# %%
for_checking_test = pd.DataFrame(y_test)
for_checking_test
# Out:
#      Thermal Conductivity(W/mK)
# 47                        61.00
# 4                         99.00
# 55                        94.00
# 26                        82.00
# 64                        71.00
# 73                        97.70
# 10                       115.00
# 40                       121.00
# 108                      121.00
# 18                       111.00
# 62                        75.00
# 11                       133.00
# 36                       119.00
# 90                       124.00
# 118                      151.00
# 110                      128.00
# 0                        102.00
# 89                       123.00
# 104                      142.00
# 65                        68.50
# 31                        66.70
# 70                        82.56
# 15                       112.00
# 115                      145.00
# 76                        94.00
# 98                       154.00
# 24                       133.00
# 78                        84.00
# 22                       105.00
# 97                       149.00
# 56                        84.00
# 111                      122.00
# 30                        83.00

# %%
test_df.columns = ['Thermal Conductivity(W/mK)', 'Predicted by model', 'Percentage Error']
test_df
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error
# 47                        61.00           65.003853          6.563693
# 4                         99.00          103.751610          4.799606
# 55                        94.00           87.159027         -7.277631
# 26                        82.00           79.627899         -2.892806
# 64                        71.00           73.478058          3.490222
# 73                        97.70           97.707291          0.007462
# 10                       115.00          113.171524         -1.589979
# 40                       121.00          120.179329         -0.678241
# 108                      121.00          122.775635          1.467467
# 18                       111.00          109.949432         -0.946457
# 62                        75.00           73.478058         -2.029256
# 11                       133.00          133.952118          0.715878
# 36                       119.00           86.848129        -27.018379
# 90                       124.00          126.780502          2.242341
# 118                      151.00          153.114853          1.400565
# 110                      128.00          123.213623         -3.739357
# 0                        102.00          103.751610          1.717265
# 89                       123.00          124.209106          0.983013
# 104                      142.00          133.303207         -6.124502
# 65                        68.50           76.329353         11.429713
# 31                        66.70           69.420052          4.078038
# 70                        82.56           80.384308         -2.635286
# 15                       112.00          108.903725         -2.764532
# 115                      145.00          150.467438          3.770647
# 76                        94.00           87.375526         -7.047312
# 98                       154.00          152.990585         -0.655464
# 24                       133.00          138.300339          3.985217
# 78                        84.00           87.375526          4.018484
# 22                       105.00          110.373528          5.117645
# 97                       149.00          144.743866         -2.856466
# 56                        84.00           77.812126         -7.366516
# 111                      122.00          111.974281         -8.217802
# 30                        83.00           78.139442         -5.856093

# %%
len(test_df)
# Out:
# 33

# %%
slope_test, intercept_test, r_value_test, p_value_test, std_err_test = scipy.stats.linregress(test_df['Thermal Conductivity(W/mK)'], test_df['Predicted by model'])
r_value_test**2
# Out:
# 0.9305930304385646

# %%
test_df.plot.scatter(x='Predicted by model', y='Thermal Conductivity(W/mK)', title= "Represents test deviation in values")
plt.text(.01, .99, 'R² = {}'.format(r_value_test**2), ha='left', va='top', transform=ax.transAxes)
# Out:
# Text(0.01, 0.99, 'R² = 0.9305930304385646')

# %%
test_df.to_csv("Origin_test.csv")

# %%
new_dataframe = pd.concat([for_checking, test_df])
new_dataframe
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error
# 53                         85.0           87.285057          2.688302
# 119                       143.0          143.014709          0.010286
# 9                         105.0          106.048653          0.998717
# 33                        102.0          100.500923         -1.469683
# 25                        142.0          140.511063         -1.048547
# ..                          ...                 ...               ...
# 22                        105.0          110.373528          5.117645
# 97                        149.0          144.743866         -2.856466
# 56                         84.0           77.812126         -7.366516
# 111                       122.0          111.974281         -8.217802
# 30                         83.0           78.139442         -5.856093
#
# [119 rows x 3 columns]

# %%
import scipy
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(newer['Thermal Conductivity(W/mK)'], newer['Predicted by model'])
r_value**2
# Out:
# 0.9748362005735081

# %%
new_dataframe.plot.scatter(x='Predicted by model', y='Thermal Conductivity(W/mK)', title= "Represents all deviation in values")
plt.text(.01, .99, 'R² = {}'.format(r_value**2), ha='left', va='top', transform=ax.transAxes)
# Out:
# Text(0.01, 0.99, 'R² = 0.9748362005735081')

# %%
new_dataframe = new_dataframe.sort_index()

# %%
new_dataframe.to_csv("Checking2.csv")

# %%
for_checking['TT'] = 'Train'
for_checking
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error     TT
# 53                         85.0           85.374641          0.440755  Train
# 119                       143.0          143.339462          0.237386  Train
# 9                         105.0          105.784599          0.747237  Train
# 33                        102.0          101.868324         -0.129094  Train
# 25                        142.0          140.324249         -1.180106  Train
# ..                          ...                 ...               ...    ...
# 102                       148.0          150.395462          1.618555  Train
# 12                         88.8           93.145409          4.893478  Train
# 42                         91.9           89.648895         -2.449515  Train
# 44                         74.1           71.615303         -3.353167  Train
# 45                         66.2           65.621681         -0.873593  Train
#
# [86 rows x 4 columns]

# %%
test_df['TT'] = 'Test'
test_df
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error    TT
# 47                        61.00           69.517662         13.963380  Test
# 4                         99.00          104.500984          5.556550  Test
# 55                        94.00           87.162216         -7.274238  Test
# 26                        82.00           79.803223         -2.678997  Test
# 64                        71.00           73.588745          3.646120  Test
# 73                        97.70           97.621094         -0.080764  Test
# 10                       115.00          113.650253         -1.173693  Test
# 40                       121.00          120.299316         -0.579077  Test
# 108                      121.00          121.558846          0.461856  Test
# 18                       111.00          110.603752         -0.356980  Test
# 62                        75.00           73.588745         -1.881673  Test
# 11                       133.00          137.361603          3.279401  Test
# 36                       119.00           88.234116        -25.853684  Test
# 90                       124.00          123.165733         -0.672796  Test
# 118                      151.00          152.713379          1.134688  Test
# 110                      128.00          121.073143         -5.411607  Test
# 0                        102.00          104.500984          2.451945  Test
# 89                       123.00          122.757156         -0.197434  Test
# 104                      142.00          137.637543         -3.072153  Test
# 65                        68.50           76.898201         12.260147  Test
# 31                        66.70           66.600723         -0.148841  Test
# 70                        82.56           76.808044         -6.967000  Test
# 15                       112.00          110.040016         -1.749986  Test
# 115                      145.00          146.036423          0.714774  Test
# 76                        94.00           94.098251          0.104523  Test
# 98                       154.00          154.469299          0.304740  Test
# 24                       133.00          140.436035          5.591004  Test
# 78                        84.00           94.098251         12.021728  Test
# 22                       105.00          110.784218          5.508779  Test
# 97                       149.00          150.209000          0.811409  Test
# 56                        84.00           81.284058         -3.233265  Test
# 111                      122.00          114.096649         -6.478156  Test
# 30                        83.00           73.075935        -11.956704  Test

# %%
newer = pd.concat([test_df, for_checking])
newer
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error
# 47                         61.0           65.003853          6.563693
# 4                          99.0          103.751610          4.799606
# 55                         94.0           87.159027         -7.277631
# 26                         82.0           79.627899         -2.892806
# 64                         71.0           73.478058          3.490222
# ..                          ...                 ...               ...
# 102                       148.0          149.051697          0.710606
# 12                         88.8           90.042480          1.399190
# 42                         91.9           92.053162          0.166661
# 44                         74.1           73.924339         -0.237059
# 45                         66.2           65.796524         -0.609480
#
# [119 rows x 3 columns]

# %%
newer = newer.sort_index()

# %%
newer.to_csv('train_test_combined_121_correction.csv')

# %%
import pickle
pickle_out = open('xgboost_srbsn.pkl', 'wb')
saved_model = pickle.dump(my_model, pickle_out)
pickle_out.close()
