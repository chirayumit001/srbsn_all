# %%
import pandas as pd

#Importing data, replace with the file name of the data
df_2 = pd.read_csv(r"/home/chiru/Desktop/Codin/srbsn'/TC- SRBSN - dataset_for_analysis (After_New) - TC- SRBSN - dataset_for_analysis (10).csv.csv")

# %%
df_2
# Out:
#      Thermal Conductivity(W/mK)  Source Sintering Pressure Oxygen  \
# 0                         102.0  SRBSN2                  1   0.28
# 1                         102.4  SRBSN2                  1   0.28
# 2                         103.4  SRBSN2                  1   0.28
# 3                         101.3  SRBSN2                  1   0.28
# 4                          99.0  SRBSN2                  1   0.28
# ..                          ...     ...                ...    ...
# 117                       151.0  Extra2                  1   0.51
# 118                       143.0  Extra2                  1   0.51
# 119                       136.0  Extra2                  1   0.51
# 120                        86.0     New                  1   4.22
# 121                        50.1    New2                  1    NaN
#
#      Particle size(d50 um)  Purity Sintering Add(2:5::Y:M)    Y  Yb    M  ...  \
# 0                      8.5   99.99                     Yes  2.0   0  5.0  ...
# 1                      8.5   99.99                     Yes  2.0   0  5.0  ...
# 2                      8.5   99.99                     Yes  2.0   0  5.0  ...
# 3                      8.5   99.99                     Yes  2.0   0  5.0  ...
# 4                      8.5   99.99                     Yes  2.0   0  5.0  ...
# ..                     ...     ...                     ...  ...  ..  ...  ...
# 117                    2.7   99.99                   2.5:5  2.5   0  5.0  ...
# 118                    2.7   99.99                     3:5  3.0   0  5.0  ...
# 119                    2.7   99.99                     5:5  5.0   0  5.0  ...
# 120                    4.0   99.99                     Yes  2.0   0  5.0  ...
# 121                    3.0   98.90                     Yes  2.0   0  5.0  ...
#
#       Eu  C   Al  N2/N2:H2 = 1/0  Nitriding Temperature(degC)  \
# 0    0.0  0  0.0               1                         1400
# 1    0.0  0  0.0               1                         1400
# 2    0.0  0  0.0               1                         1400
# 3    0.0  0  0.0               1                         1400
# 4    0.0  0  0.0               1                         1400
# ..   ... ..  ...             ...                          ...
# 117  0.0  0  0.0               1                         1400
# 118  0.0  0  0.0               1                         1400
# 119  0.0  0  0.0               1                         1400
# 120  0.0  0  0.0               1                         1400
# 121  0.0  0  0.0               1                          400
#
#      Nitriding Time(h)  Sintering Temperature(degC)  Sintering Time(h)  \
# 0                  4.0                         1850                 60
# 1                  4.0                         1850                 60
# 2                  4.0                         1850                 60
# 3                  4.0                         1850                 60
# 4                  4.0                         1850                 60
# ..                 ...                          ...                ...
# 117                4.0                         1900                 24
# 118                4.0                         1900                 24
# 119                4.0                         1900                 24
# 120                6.0                         1900                 12
# 121                4.0                         1850                 20
#
#          RD  Verified
# 0     99.30       Yes
# 1    100.00       Yes
# 2     99.00       Yes
# 3     97.50       Yes
# 4     97.60       Yes
# ..      ...       ...
# 117   99.20       NaN
# 118   99.10       NaN
# 119   98.50       NaN
# 120   99.23       NaN
# 121     NaN       NaN
#
# [122 rows x 22 columns]

# %%
df = df_2.drop('Sintering Add(2:5::Y:M)', axis = 1)
df = df.drop('Verified', axis=1)
df = df.drop("RD", axis = 1)
df = df.drop("C", axis=1)
df = df.drop("Yb", axis=1)
df = df.drop("Mn", axis=1)
df = df.drop("L", axis=1)
df = df.drop("Eu", axis=1)

df = df.drop('Source', axis = 1)
# df.drop("Oxygen", axis = 1, inplace = True)
df
# Out:
#      Thermal Conductivity(W/mK) Sintering Pressure Oxygen  \
# 0                         102.0                  1   0.28
# 1                         102.4                  1   0.28
# 2                         103.4                  1   0.28
# 3                         101.3                  1   0.28
# 4                          99.0                  1   0.28
# ..                          ...                ...    ...
# 117                       151.0                  1   0.51
# 118                       143.0                  1   0.51
# 119                       136.0                  1   0.51
# 120                        86.0                  1   4.22
# 121                        50.1                  1    NaN
#
#      Particle size(d50 um)  Purity    Y    M   Al  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99  2.0  5.0  0.0               1
# 1                      8.5   99.99  2.0  5.0  0.0               1
# 2                      8.5   99.99  2.0  5.0  0.0               1
# 3                      8.5   99.99  2.0  5.0  0.0               1
# 4                      8.5   99.99  2.0  5.0  0.0               1
# ..                     ...     ...  ...  ...  ...             ...
# 117                    2.7   99.99  2.5  5.0  0.0               1
# 118                    2.7   99.99  3.0  5.0  0.0               1
# 119                    2.7   99.99  5.0  5.0  0.0               1
# 120                    4.0   99.99  2.0  5.0  0.0               1
# 121                    3.0   98.90  2.0  5.0  0.0               1
#
#      Nitriding Temperature(degC)  Nitriding Time(h)  \
# 0                           1400                4.0
# 1                           1400                4.0
# 2                           1400                4.0
# 3                           1400                4.0
# 4                           1400                4.0
# ..                           ...                ...
# 117                         1400                4.0
# 118                         1400                4.0
# 119                         1400                4.0
# 120                         1400                6.0
# 121                          400                4.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 0                           1850                 60
# 1                           1850                 60
# 2                           1850                 60
# 3                           1850                 60
# 4                           1850                 60
# ..                           ...                ...
# 117                         1900                 24
# 118                         1900                 24
# 119                         1900                 24
# 120                         1900                 12
# 121                         1850                 20
#
# [122 rows x 13 columns]

# %%
import numpy as np
df['Sintering Pressure'] = np.where((df['Sintering Pressure'] == 'Not mentioned'), 1, df['Sintering Pressure'])
df
# Out:
#      Thermal Conductivity(W/mK) Sintering Pressure Oxygen  \
# 0                         102.0                  1   0.28
# 1                         102.4                  1   0.28
# 2                         103.4                  1   0.28
# 3                         101.3                  1   0.28
# 4                          99.0                  1   0.28
# ..                          ...                ...    ...
# 117                       151.0                  1   0.51
# 118                       143.0                  1   0.51
# 119                       136.0                  1   0.51
# 120                        86.0                  1   4.22
# 121                        50.1                  1    NaN
#
#      Particle size(d50 um)  Purity    Y    M   Al  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99  2.0  5.0  0.0               1
# 1                      8.5   99.99  2.0  5.0  0.0               1
# 2                      8.5   99.99  2.0  5.0  0.0               1
# 3                      8.5   99.99  2.0  5.0  0.0               1
# 4                      8.5   99.99  2.0  5.0  0.0               1
# ..                     ...     ...  ...  ...  ...             ...
# 117                    2.7   99.99  2.5  5.0  0.0               1
# 118                    2.7   99.99  3.0  5.0  0.0               1
# 119                    2.7   99.99  5.0  5.0  0.0               1
# 120                    4.0   99.99  2.0  5.0  0.0               1
# 121                    3.0   98.90  2.0  5.0  0.0               1
#
#      Nitriding Temperature(degC)  Nitriding Time(h)  \
# 0                           1400                4.0
# 1                           1400                4.0
# 2                           1400                4.0
# 3                           1400                4.0
# 4                           1400                4.0
# ..                           ...                ...
# 117                         1400                4.0
# 118                         1400                4.0
# 119                         1400                4.0
# 120                         1400                6.0
# 121                          400                4.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 0                           1850                 60
# 1                           1850                 60
# 2                           1850                 60
# 3                           1850                 60
# 4                           1850                 60
# ..                           ...                ...
# 117                         1900                 24
# 118                         1900                 24
# 119                         1900                 24
# 120                         1900                 12
# 121                         1850                 20
#
# [122 rows x 13 columns]

# %%
df['Oxygen'] = np.where((df['Oxygen'] == 'After milling data only'), 0.3, df['Oxygen'])
df
# Out:
#      Thermal Conductivity(W/mK) Sintering Pressure Oxygen  \
# 0                         102.0                  1   0.28
# 1                         102.4                  1   0.28
# 2                         103.4                  1   0.28
# 3                         101.3                  1   0.28
# 4                          99.0                  1   0.28
# ..                          ...                ...    ...
# 117                       151.0                  1   0.51
# 118                       143.0                  1   0.51
# 119                       136.0                  1   0.51
# 120                        86.0                  1   4.22
# 121                        50.1                  1    NaN
#
#      Particle size(d50 um)  Purity    Y    M   Al  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99  2.0  5.0  0.0               1
# 1                      8.5   99.99  2.0  5.0  0.0               1
# 2                      8.5   99.99  2.0  5.0  0.0               1
# 3                      8.5   99.99  2.0  5.0  0.0               1
# 4                      8.5   99.99  2.0  5.0  0.0               1
# ..                     ...     ...  ...  ...  ...             ...
# 117                    2.7   99.99  2.5  5.0  0.0               1
# 118                    2.7   99.99  3.0  5.0  0.0               1
# 119                    2.7   99.99  5.0  5.0  0.0               1
# 120                    4.0   99.99  2.0  5.0  0.0               1
# 121                    3.0   98.90  2.0  5.0  0.0               1
#
#      Nitriding Temperature(degC)  Nitriding Time(h)  \
# 0                           1400                4.0
# 1                           1400                4.0
# 2                           1400                4.0
# 3                           1400                4.0
# 4                           1400                4.0
# ..                           ...                ...
# 117                         1400                4.0
# 118                         1400                4.0
# 119                         1400                4.0
# 120                         1400                6.0
# 121                          400                4.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 0                           1850                 60
# 1                           1850                 60
# 2                           1850                 60
# 3                           1850                 60
# 4                           1850                 60
# ..                           ...                ...
# 117                         1900                 24
# 118                         1900                 24
# 119                         1900                 24
# 120                         1900                 12
# 121                         1850                 20
#
# [122 rows x 13 columns]

# %%
np.where(df['Sintering Pressure'] ==0.1)
# Out:
# (array([], dtype=int64),)

# %%
df = df.astype(float)

# %%
df['Oxygen'].fillna(0.3, inplace=True)
df
# Out:
#      Thermal Conductivity(W/mK)  Sintering Pressure  Oxygen  \
# 0                         102.0                 1.0    0.28
# 1                         102.4                 1.0    0.28
# 2                         103.4                 1.0    0.28
# 3                         101.3                 1.0    0.28
# 4                          99.0                 1.0    0.28
# ..                          ...                 ...     ...
# 117                       151.0                 1.0    0.51
# 118                       143.0                 1.0    0.51
# 119                       136.0                 1.0    0.51
# 120                        86.0                 1.0    4.22
# 121                        50.1                 1.0    0.30
#
#      Particle size(d50 um)  Purity    Y    M   Al  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99  2.0  5.0  0.0             1.0
# 1                      8.5   99.99  2.0  5.0  0.0             1.0
# 2                      8.5   99.99  2.0  5.0  0.0             1.0
# 3                      8.5   99.99  2.0  5.0  0.0             1.0
# 4                      8.5   99.99  2.0  5.0  0.0             1.0
# ..                     ...     ...  ...  ...  ...             ...
# 117                    2.7   99.99  2.5  5.0  0.0             1.0
# 118                    2.7   99.99  3.0  5.0  0.0             1.0
# 119                    2.7   99.99  5.0  5.0  0.0             1.0
# 120                    4.0   99.99  2.0  5.0  0.0             1.0
# 121                    3.0   98.90  2.0  5.0  0.0             1.0
#
#      Nitriding Temperature(degC)  Nitriding Time(h)  \
# 0                         1400.0                4.0
# 1                         1400.0                4.0
# 2                         1400.0                4.0
# 3                         1400.0                4.0
# 4                         1400.0                4.0
# ..                           ...                ...
# 117                       1400.0                4.0
# 118                       1400.0                4.0
# 119                       1400.0                4.0
# 120                       1400.0                6.0
# 121                        400.0                4.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 0                         1850.0               60.0
# 1                         1850.0               60.0
# 2                         1850.0               60.0
# 3                         1850.0               60.0
# 4                         1850.0               60.0
# ..                           ...                ...
# 117                       1900.0               24.0
# 118                       1900.0               24.0
# 119                       1900.0               24.0
# 120                       1900.0               12.0
# 121                       1850.0               20.0
#
# [122 rows x 13 columns]

# %%
df.isnull().values.sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                              Thermal Conductivity(W/mK)  Sintering Pressure  \
# Thermal Conductivity(W/mK)                     1.000000            0.381196
# Sintering Pressure                             0.381196            1.000000
# Oxygen                                        -0.075293            0.078526
# Particle size(d50 um)                          0.222712            0.247585
# Purity                                         0.400050            0.437746
# Y                                              0.036843           -0.188272
# M                                              0.028325           -0.080408
# Al                                            -0.215540           -0.030437
# N2/N2:H2 = 1/0                                 0.380488           -0.035527
# Nitriding Temperature(degC)                    0.193742            0.065347
# Nitriding Time(h)                             -0.040256           -0.162312
# Sintering Temperature(degC)                    0.290951            0.606780
# Sintering Time(h)                              0.380449            0.160454
#
#                                Oxygen  Particle size(d50 um)    Purity  \
# Thermal Conductivity(W/mK)  -0.075293               0.222712  0.400050
# Sintering Pressure           0.078526               0.247585  0.437746
# Oxygen                       1.000000              -0.084520  0.117606
# Particle size(d50 um)       -0.084520               1.000000  0.452902
# Purity                       0.117606               0.452902  1.000000
# Y                           -0.049239              -0.100207 -0.254180
# M                           -0.199468              -0.167842 -0.220985
# Al                           0.188536              -0.095523  0.075226
# N2/N2:H2 = 1/0               0.041925               0.074230 -0.187460
# Nitriding Temperature(degC)  0.067886               0.082539  0.401290
# Nitriding Time(h)            0.184842               0.044325 -0.323166
# Sintering Temperature(degC)  0.105837              -0.220109  0.075771
# Sintering Time(h)           -0.126184               0.376356  0.170703
#
#                                     Y         M        Al  N2/N2:H2 = 1/0  \
# Thermal Conductivity(W/mK)   0.036843  0.028325 -0.215540        0.380488
# Sintering Pressure          -0.188272 -0.080408 -0.030437       -0.035527
# Oxygen                      -0.049239 -0.199468  0.188536        0.041925
# Particle size(d50 um)       -0.100207 -0.167842 -0.095523        0.074230
# Purity                      -0.254180 -0.220985  0.075226       -0.187460
# Y                            1.000000  0.085283 -0.001060        0.243097
# M                            0.085283  1.000000 -0.254945       -0.045880
# Al                          -0.001060 -0.254945  1.000000        0.060833
# N2/N2:H2 = 1/0               0.243097 -0.045880  0.060833        1.000000
# Nitriding Temperature(degC) -0.078963 -0.093842  0.017929       -0.186783
# Nitriding Time(h)            0.207761 -0.378388  0.182311        0.586535
# Sintering Temperature(degC) -0.144843 -0.132165  0.040642        0.048788
# Sintering Time(h)            0.006754  0.112878 -0.075966        0.273106
#
#                              Nitriding Temperature(degC)  Nitriding Time(h)  \
# Thermal Conductivity(W/mK)                      0.193742          -0.040256
# Sintering Pressure                              0.065347          -0.162312
# Oxygen                                          0.067886           0.184842
# Particle size(d50 um)                           0.082539           0.044325
# Purity                                          0.401290          -0.323166
# Y                                              -0.078963           0.207761
# M                                              -0.093842          -0.378388
# Al                                              0.017929           0.182311
# N2/N2:H2 = 1/0                                 -0.186783           0.586535
# Nitriding Temperature(degC)                     1.000000          -0.116977
# Nitriding Time(h)                              -0.116977           1.000000
# Sintering Temperature(degC)                     0.123125          -0.003230
# Sintering Time(h)                              -0.045364          -0.100396
#
#                              Sintering Temperature(degC)  Sintering Time(h)
# Thermal Conductivity(W/mK)                      0.290951           0.380449
# Sintering Pressure                              0.606780           0.160454
# Oxygen                                          0.105837          -0.126184
# Particle size(d50 um)                          -0.220109           0.376356
# Purity                                          0.075771           0.170703
# Y                                              -0.144843           0.006754
# M                                              -0.132165           0.112878
# Al                                              0.040642          -0.075966
# N2/N2:H2 = 1/0                                  0.048788           0.273106
# Nitriding Temperature(degC)                     0.123125          -0.045364
# Nitriding Time(h)                              -0.003230          -0.100396
# Sintering Temperature(degC)                     1.000000          -0.109404
# Sintering Time(h)                              -0.109404           1.000000

# %%
normalized_df=(df-df.mean())/df.std()
tc_std = df['Thermal Conductivity(W/mK)'].std()
tc_mean = df['Thermal Conductivity(W/mK)'].mean()

# %%
# normalized_df['Sintering Pressure'].head(50)
(normalized_df['Thermal Conductivity(W/mK)']*tc_std)+tc_mean
# Out:
# 0      102.0
# 1      102.4
# 2      103.4
# 3      101.3
# 4       99.0
#        ...
# 117    151.0
# 118    143.0
# 119    136.0
# 120     86.0
# 121     50.1
# Name: Thermal Conductivity(W/mK), Length: 122, dtype: float64

# %%
import seaborn as sns
# %matplotlib inline

# load the Auto dataset
auto_df = df

# calculate the correlation matrix on the numeric columns
corr = auto_df.select_dtypes('number').corr()

# plot the heatmap
sns.heatmap(corr)
# Out:
# <AxesSubplot: >

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
correlation_plot = df.corr()['Thermal Conductivity(W/mK)'][1:].plot(kind='barh')
correlation_plot
# Out:
# <AxesSubplot: >

# %%
import matplotlib.pyplot as plt


plt.scatter(df['Thermal Conductivity(W/mK)'], df['Particle size(d50 um)'])

# %%
data = df
fig, ax = plt.subplots()
data['Thermal Conductivity(W/mK)'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot: xlabel='Thermal Conductivity(W/mK)'>

# %%
X = df.drop('Thermal Conductivity(W/mK)',axis=1)
y = df['Thermal Conductivity(W/mK)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

# %%
X_test
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)  Purity     Y    M  \
# 18                  1.0    0.30                   7.00   99.91  2.00  0.0
# 45                  0.9    1.09                   1.68   99.99  2.00  0.0
# 47                  0.1    0.30                   1.00   99.00  2.00  5.0
# 89                  1.0    0.51                   2.70   99.99  2.00  3.0
# 4                   1.0    0.28                   8.50   99.99  2.00  5.0
# 40                  1.0    0.30                   7.00   99.91  2.00  0.0
# 62                  0.9    0.30                   1.00   99.90  2.00  5.0
# 107                 1.0    0.51                   2.70   99.99  1.50  5.0
# 31                  0.1    0.30                   1.00   99.00  5.00  5.0
# 55                  1.0    0.30                   1.00   99.00  5.00  5.0
# 53                  1.0    0.30                   1.00   99.00  1.00  5.0
# 119                 1.0    0.51                   2.70   99.99  5.00  5.0
# 10                  1.0    0.28                   2.70   99.99  2.00  5.0
# 90                  1.0    0.51                   2.70   99.99  2.00  4.0
# 109                 1.0    0.51                   2.70   99.99  2.50  5.0
# 11                  1.0    0.28                   2.70   99.99  2.00  5.0
# 76                  1.0    0.46                   4.35   99.99  1.92  5.0
# 56                  1.0    0.30                   1.00   99.00  0.50  5.0
# 115                 1.0    0.51                   2.70   99.99  1.50  5.0
#
#       Al  N2/N2:H2 = 1/0  Nitriding Temperature(degC)  Nitriding Time(h)  \
# 18   0.0             1.0                       1400.0                8.0
# 45   0.4             1.0                       1400.0                8.0
# 47   0.0             1.0                       1350.0                6.0
# 89   0.0             1.0                       1400.0                4.0
# 4    0.0             1.0                       1400.0                4.0
# 40   0.0             1.0                       1400.0                8.0
# 62   0.0             0.0                       1450.0                0.0
# 107  0.0             1.0                       1400.0                4.0
# 31   0.0             1.0                       1350.0                8.0
# 55   0.0             1.0                       1350.0                6.0
# 53   0.0             1.0                       1350.0                6.0
# 119  0.0             1.0                       1400.0                4.0
# 10   0.0             1.0                       1400.0                8.0
# 90   0.0             1.0                       1400.0                4.0
# 109  0.0             1.0                       1400.0                4.0
# 11   0.0             1.0                       1400.0                8.0
# 76   0.0             0.0                       1400.0                4.0
# 56   0.0             1.0                       1350.0                6.0
# 115  0.0             1.0                       1400.0                4.0
#
#      Sintering Temperature(degC)  Sintering Time(h)
# 18                        1900.0                6.0
# 45                        1900.0                6.0
# 47                        1800.0                6.0
# 89                        1900.0                6.0
# 4                         1850.0               60.0
# 40                        1900.0               24.0
# 62                        1900.0                6.0
# 107                       1900.0                6.0
# 31                        1800.0                6.0
# 55                        1950.0                6.0
# 53                        1950.0                6.0
# 119                       1900.0               24.0
# 10                        1900.0               12.0
# 90                        1900.0                6.0
# 109                       1900.0                6.0
# 11                        1900.0               24.0
# 76                        1900.0                4.0
# 56                        1950.0               18.0
# 115                       1900.0               24.0

# %%
df.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<AxesSubplot: title={'center': 'Thermal Conductivity(W/mK)'}>,
#         <AxesSubplot: title={'center': 'Sintering Pressure'}>,
#         <AxesSubplot: title={'center': 'Oxygen'}>,
#         <AxesSubplot: title={'center': 'Particle size(d50 um)'}>],
#        [<AxesSubplot: title={'center': 'Purity'}>,
#         <AxesSubplot: title={'center': 'Y'}>,
#         <AxesSubplot: title={'center': 'M'}>,
#         <AxesSubplot: title={'center': 'Al'}>],
#        [<AxesSubplot: title={'center': 'N2/N2:H2 = 1/0'}>,
#         <AxesSubplot: title={'center': 'Nitriding Temperature(degC)'}>,
#         <AxesSubplot: title={'center': 'Nitriding Time(h)'}>,
#         <AxesSubplot: title={'center': 'Sintering Temperature(degC)'}>],
#        [<AxesSubplot: title={'center': 'Sintering Time(h)'}>,
#         <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %%
len(y_train), len(X_train), len(X_test), len(y_test)
# Out:
# (103, 103, 19, 19)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

# my_model = XGBRegressor(max_depth = 2)
# # Add silent=True to avoid printing out updates with each cycle
# my_model.fit(X_train, y_train, verbose=True)

# Define the hyperparameter grid
param_grid = {
        'min_child_weight': [1, 3, 5, 8, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [2, 3, 4, 5, 10]
        }
# param_grid = {'gamma': [0.5, 1, 1.5, 2, 5]}
# Create the XGBoost model object
xgb_model = XGBRegressor() 

# Create the GridSearchCV object
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')

# Fit the GridSearchCV object to the training data
results = grid_search.fit(X_train, y_train)
results
# Print the best set of hyperparameters and the corresponding score
print("Best set of hyperparameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
grid_search.cv_results_['mean_test_score']

# %%
max(grid_search.cv_results_['mean_test_score'])
# Out:
# 0.7476018754281901

# %%
from xgboost import XGBRegressor

# grid_search.best_params_
# {'colsample_bytree': 0.6, 'gamma': 5, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8}
#  {'colsample_bytree': 0.6, 'gamma': 2, 'max_depth': 15, 'min_child_weight': 1, 'subsample': 1.0}
my_model = XGBRegressor(colsample_bytree = 0.8, gamma = 2, max_depth = 5, min_child_weight = 1, subsample = 0.6)
# Add silent=True to avoid printing out updates with each cycle{'colsample_bytree': 1.0, 'gamma': 1, 'max_depth': 2, 'min_child_weight': 1, 'subsample': 1.0}
my_model.fit(X_train, y_train, verbose=True)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=2, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# make predictions
predictions = my_model.predict(X_test)
len(predictions)
# Out:
# 19

# %%
#Prediction on training data
peri = my_model.predict(X_train)
peri
# Out:
# array([103.76871 ,  82.42095 ,  67.51441 ,  73.66742 , 155.1079  ,
#        133.52145 ,  84.31767 ,  98.62997 , 106.80263 ,  87.839836,
#        152.9385  ,  88.91044 , 111.555534,  97.01548 , 107.27637 ,
#        152.9385  , 122.84858 , 111.192795,  85.189674,  89.67089 ,
#         73.66742 , 105.72216 , 102.20761 , 140.54207 ,  63.25599 ,
#         86.88817 ,  87.54151 , 106.80321 , 103.76871 ,  73.66742 ,
#         80.44101 , 120.395874,  79.092224, 102.20761 , 112.06011 ,
#         72.16125 , 102.20761 , 111.58844 ,  76.68378 ,  73.55592 ,
#         55.287395,  90.60696 , 103.84439 ,  91.82658 , 120.395874,
#        154.65648 , 124.9524  , 100.13719 ,  98.405136, 111.98366 ,
#        103.76871 , 120.395874, 108.51781 , 100.095665,  66.806   ,
#         96.933945,  58.96369 , 149.73106 ,  94.52482 ,  84.90136 ,
#        106.863106,  61.014084,  66.62267 ,  72.16125 , 145.31754 ,
#        103.84439 , 114.123985,  90.4939  , 109.654396,  66.2223  ,
#        122.41904 , 150.34688 , 108.292625,  89.67089 ,  75.182175,
#        143.46278 ,  94.4644  ,  72.16125 , 149.78302 ,  87.839836,
#         74.41038 , 122.84858 , 103.76871 ,  84.78461 , 100.897156,
#        103.76871 , 115.78119 , 140.24274 , 156.1172  , 116.66093 ,
#        120.225685,  64.02562 , 100.38882 , 107.78132 ,  50.14286 ,
#        133.16008 ,  72.16125 ,  89.75243 , 115.644424, 100.9485  ,
#        119.37997 ,  75.02604 , 143.83713 ], dtype=float32)

# %%
len(peri)
# Out:
# 103

# %%
import scipy

slope_train, intercept_train, r_value_train, p_value_train, std_err_train = scipy.stats.linregress(y_train, peri)
r_value_train**2
# Out:
# 0.9850993057848566

# %%
f = pd.DataFrame(y_train)
f['Predictions'] = peri

# %%
f.plot.scatter(x='Predictions', y='Thermal Conductivity(W/mK)', title= "Represents training set deviation in values")
plt.text(.01, .99, 'R² = {}'.format(r_value_train**2), ha='left', va='top', transform=ax.transAxes)
plt.savefig('train_r2.png')

# %%
slope_test, intercept_test, r_value_test, p_value_test, std_err_test = scipy.stats.linregress(y_test, predictions)
r_value_test**2
# Out:
# 0.9689209474450404

# %%
test_df = pd.DataFrame()
test_df['Thermal Conductivity(W/mK)'] = y_test
test_df['Predicted by model'] = predictions

# %%
test_df.plot.scatter(x='Predicted by model', y='Thermal Conductivity(W/mK)', title= "Represents test deviation in values")
plt.text(.01, .99, 'R² = {}'.format(r_value_test**2), ha='left', va='top', transform=ax.transAxes)
plt.savefig('test_r2.png')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import pandas as pd

# Compute RMSE, MAE, MAPE
def calculate_metrics(y_true, y_pred):
    rmse = mean_squared_error(y_true, y_pred, squared=False)  # RMSE
    mae = mean_absolute_error(y_true, y_pred)  # MAE
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100  # MAPE (%)
    return rmse, mae, mape

# Train and Test metrics
rmse_train, mae_train, mape_train = calculate_metrics(y_train, y_train_pred)
rmse_test, mae_test, mape_test = calculate_metrics(y_test, y_test_pred)

# Create a results table
metrics_table = pd.DataFrame({
    "Metric": ["RMSE", "MAE", "MAPE (%)"],
    "Train": [rmse_train, mae_train, mape_train],
    "Test": [rmse_test, mae_test, mape_test]
})

# Print table
print(metrics_table.to_string(index=False))
# Out:
#   Metric    Train     Test
#     RMSE 3.138431 5.623780
#      MAE 1.715551 4.188182
# MAPE (%) 1.809766 4.358819
# /usr/lib/python3/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/lib/python3/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
