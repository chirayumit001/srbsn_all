# %%
# !pip install pandas
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# ...

# %%
import pandas as pd

df_2 = pd.read_csv(r"/home/chiru/Desktop/Codin/srbsn'/TC- SRBSN - dataset_for_analysis (After_New) - TC- SRBSN - dataset_for_analysis (10).csv.csv")

# %%
df_2
# Out:
#      Thermal Conductivity(W/mK)  Source Sintering Pressure Oxygen  \
# 0                         102.0  SRBSN2                  1   0.28
# 1                         102.4  SRBSN2                  1   0.28
# 2                         103.4  SRBSN2                  1   0.28
# 3                         101.3  SRBSN2                  1   0.28
# 4                          99.0  SRBSN2                  1   0.28
# ..                          ...     ...                ...    ...
# 117                       151.0  Extra2                  1   0.51
# 118                       143.0  Extra2                  1   0.51
# 119                       136.0  Extra2                  1   0.51
# 120                        86.0     New                  1   4.22
# 121                        50.1    New2                  1    NaN
#
#      Particle size(d50 um)  Purity Sintering Add(2:5::Y:M)    Y  Yb    M  ...  \
# 0                      8.5   99.99                     Yes  2.0   0  5.0  ...
# ...

# %%
# df3 = df_2

# %%
# bins = [50,60,70,80,90,100,110,120,130,140,150,160]
# df3['binned'] = pd.cut(df3['Thermal Conductivity(W/mK)'], bins)

# %%
# df3['Thermal Conductivity(W/mK)'].hist(figsize=(5, 5), bins=10, xlabelsize=8, ylabelsize=8)

# %%
df = df_2.drop('Sintering Add(2:5::Y:M)', axis = 1)
df = df.drop('Verified', axis=1)
df = df.drop("RD", axis = 1)
df = df.drop("C", axis=1)
df = df.drop("Yb", axis=1)
df = df.drop("Mn", axis=1)
df = df.drop("L", axis=1)
df = df.drop("Eu", axis=1)

df = df.drop('Source', axis = 1)
# df.drop("Oxygen", axis = 1, inplace = True)
df
# Out:
#      Thermal Conductivity(W/mK) Sintering Pressure Oxygen  \
# 0                         102.0                  1   0.28
# 1                         102.4                  1   0.28
# 2                         103.4                  1   0.28
# 3                         101.3                  1   0.28
# 4                          99.0                  1   0.28
# ..                          ...                ...    ...
# 117                       151.0                  1   0.51
# 118                       143.0                  1   0.51
# 119                       136.0                  1   0.51
# 120                        86.0                  1   4.22
# 121                        50.1                  1    NaN
#
#      Particle size(d50 um)  Purity    Y    M   Al  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99  2.0  5.0  0.0               1
# 1                      8.5   99.99  2.0  5.0  0.0               1
# 2                      8.5   99.99  2.0  5.0  0.0               1
# ...

# %%
import numpy as np
df['Sintering Pressure'] = np.where((df['Sintering Pressure'] == 'Not mentioned'), 1, df['Sintering Pressure'])
df
# Out:
#      Thermal Conductivity(W/mK) Sintering Pressure Oxygen  \
# 0                         102.0                  1   0.28
# 1                         102.4                  1   0.28
# 2                         103.4                  1   0.28
# 3                         101.3                  1   0.28
# 4                          99.0                  1   0.28
# ..                          ...                ...    ...
# 117                       151.0                  1   0.51
# 118                       143.0                  1   0.51
# 119                       136.0                  1   0.51
# 120                        86.0                  1   4.22
# 121                        50.1                  1    NaN
#
#      Particle size(d50 um)  Purity    Y    M   Al  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99  2.0  5.0  0.0               1
# 1                      8.5   99.99  2.0  5.0  0.0               1
# 2                      8.5   99.99  2.0  5.0  0.0               1
# ...

# %%
df['Oxygen'] = np.where((df['Oxygen'] == 'After milling data only'), 0.3, df['Oxygen'])
df
# Out:
#      Thermal Conductivity(W/mK) Sintering Pressure Oxygen  \
# 0                         102.0                  1   0.28
# 1                         102.4                  1   0.28
# 2                         103.4                  1   0.28
# 3                         101.3                  1   0.28
# 4                          99.0                  1   0.28
# ..                          ...                ...    ...
# 117                       151.0                  1   0.51
# 118                       143.0                  1   0.51
# 119                       136.0                  1   0.51
# 120                        86.0                  1   4.22
# 121                        50.1                  1    NaN
#
#      Particle size(d50 um)  Purity    Y    M   Al  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99  2.0  5.0  0.0               1
# 1                      8.5   99.99  2.0  5.0  0.0               1
# 2                      8.5   99.99  2.0  5.0  0.0               1
# ...

# %%
np.where(df['Sintering Pressure'] ==0.1)
# Out:
# (array([], dtype=int64),)

# %%
df = df.astype(float)

# %%
df['Oxygen'].fillna(0.3, inplace=True)
df
# Out:
#      Thermal Conductivity(W/mK)  Sintering Pressure  Oxygen  \
# 0                         102.0                 1.0    0.28
# 1                         102.4                 1.0    0.28
# 2                         103.4                 1.0    0.28
# 3                         101.3                 1.0    0.28
# 4                          99.0                 1.0    0.28
# ..                          ...                 ...     ...
# 117                       151.0                 1.0    0.51
# 118                       143.0                 1.0    0.51
# 119                       136.0                 1.0    0.51
# 120                        86.0                 1.0    4.22
# 121                        50.1                 1.0    0.30
#
#      Particle size(d50 um)  Purity    Y    M   Al  N2/N2:H2 = 1/0  \
# 0                      8.5   99.99  2.0  5.0  0.0             1.0
# 1                      8.5   99.99  2.0  5.0  0.0             1.0
# ...

# %%
df.isnull().values.sum()
# Out:
# 0

# %%
df.corr()
# Out:
#                              Thermal Conductivity(W/mK)  Sintering Pressure  \
# Thermal Conductivity(W/mK)                     1.000000            0.381196
# Sintering Pressure                             0.381196            1.000000
# Oxygen                                        -0.075293            0.078526
# Particle size(d50 um)                          0.222712            0.247585
# Purity                                         0.400050            0.437746
# Y                                              0.036843           -0.188272
# M                                              0.028325           -0.080408
# Al                                            -0.215540           -0.030437
# N2/N2:H2 = 1/0                                 0.380488           -0.035527
# Nitriding Temperature(degC)                    0.193742            0.065347
# Nitriding Time(h)                             -0.040256           -0.162312
# ...

# %%
df.to_csv("10thdf.csv")

# %%
normalized_df=(df-df.mean())/df.std()
tc_std = df['Thermal Conductivity(W/mK)'].std()
tc_mean = df['Thermal Conductivity(W/mK)'].mean()

# %%
# normalized_df['Sintering Pressure'].head(50)
(normalized_df['Thermal Conductivity(W/mK)']*tc_std)+tc_mean
# Out:
# 0      102.0
# 1      102.4
# 2      103.4
# 3      101.3
# 4       99.0
#        ...
# 117    151.0
# 118    143.0
# 119    136.0
# 120     86.0
# 121     50.1
# Name: Thermal Conductivity(W/mK), Length: 122, dtype: float64

# %%
import seaborn as sns
# %matplotlib inline

# load the Auto dataset
auto_df = df

# calculate the correlation matrix on the numeric columns
corr = auto_df.select_dtypes('number').corr()

# plot the heatmap
sns.heatmap(corr)
# Out:
# <AxesSubplot: >

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
correlation_plot = df.corr()['Thermal Conductivity(W/mK)'][1:].plot(kind='barh')
correlation_plot
# Out:
# <AxesSubplot: >

# %%
import matplotlib.pyplot as plt


plt.scatter(df['Thermal Conductivity(W/mK)'], df['Particle size(d50 um)'])

# %%
data = df
fig, ax = plt.subplots()
data['Thermal Conductivity(W/mK)'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot: xlabel='Thermal Conductivity(W/mK)'>

# %%
X = df.drop('Thermal Conductivity(W/mK)',axis=1)
y = df['Thermal Conductivity(W/mK)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

# %%
X_test
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)  Purity     Y    M  \
# 18                  1.0    0.30                   7.00   99.91  2.00  0.0
# 45                  0.9    1.09                   1.68   99.99  2.00  0.0
# 47                  0.1    0.30                   1.00   99.00  2.00  5.0
# 89                  1.0    0.51                   2.70   99.99  2.00  3.0
# 4                   1.0    0.28                   8.50   99.99  2.00  5.0
# 40                  1.0    0.30                   7.00   99.91  2.00  0.0
# 62                  0.9    0.30                   1.00   99.90  2.00  5.0
# 107                 1.0    0.51                   2.70   99.99  1.50  5.0
# 31                  0.1    0.30                   1.00   99.00  5.00  5.0
# 55                  1.0    0.30                   1.00   99.00  5.00  5.0
# 53                  1.0    0.30                   1.00   99.00  1.00  5.0
# 119                 1.0    0.51                   2.70   99.99  5.00  5.0
# ...

# %%
pd.DataFrame(X.iloc[45]).T
# Out:
#     Sintering Pressure  Oxygen  Particle size(d50 um)  Purity    Y    M   Al  \
# 45                 0.9    1.09                   1.68   99.99  2.0  0.0  0.4
#
#     N2/N2:H2 = 1/0  Nitriding Temperature(degC)  Nitriding Time(h)  \
# 45             1.0                       1400.0                8.0
#
#     Sintering Temperature(degC)  Sintering Time(h)
# 45                       1900.0                6.0

# %%
# X.drop(32).head(37)
# t.head(37)

# %%
# X

# %%
X.loc[32]
# Out:
# Sintering Pressure                1.0
# Oxygen                            0.3
# Particle size(d50 um)             1.0
# Purity                           99.0
# Y                                 5.0
# M                                 5.0
# Al                                0.0
# N2/N2:H2 = 1/0                    1.0
# Nitriding Temperature(degC)    1350.0
# Nitriding Time(h)                 8.0
# Sintering Temperature(degC)    1900.0
# Sintering Time(h)                 6.0
# Name: 32, dtype: float64

# %%
y_test[y_test == 119]
# Out:
# Series([], Name: Thermal Conductivity(W/mK), dtype: float64)

# %%
X_test[X_test['Particle size(d50 um)']==1.68]
# Out:
#     Sintering Pressure  Oxygen  Particle size(d50 um)  Purity    Y    M   Al  \
# 45                 0.9    1.09                   1.68   99.99  2.0  0.0  0.4
#
#     N2/N2:H2 = 1/0  Nitriding Temperature(degC)  Nitriding Time(h)  \
# 45             1.0                       1400.0                8.0
#
#     Sintering Temperature(degC)  Sintering Time(h)
# 45                       1900.0                6.0

# %%
# t = X_test[X_test['Particle size(d50 um)']==5.270]
# t = pd.DataFrame(X.iloc[12]).T
# u = pd.DataFrame(X.iloc[42]).T
# v = pd.DataFrame(X.iloc[44]).T
# w = pd.DataFrame(X.iloc[45]).T
# X_train = pd.concat([X_train, t, u, v, w])
X_train
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)  Purity    Y    M   Al  \
# 0                   1.0    0.28                  8.500  99.990  2.0  5.0  0.0
# 26                  0.9    0.30                  1.676  99.999  2.0  0.0  0.0
# 44                  0.9    1.09                  1.680  99.990  2.0  0.0  0.2
# 66                  0.9    0.30                  1.000  99.900  1.0  3.0  0.0
# 98                  1.0    0.51                  2.700  99.990  2.0  3.0  0.0
# ..                  ...     ...                    ...     ...  ...  ...  ...
# 106                 1.0    0.51                  2.700  99.990  1.0  5.0  0.0
# 14                  0.9    0.28                  8.500  99.990  2.0  5.0  0.0
# 92                  1.0    0.51                  2.700  99.990  2.0  6.0  0.0
# 51                  1.0    0.30                  1.000  99.000  5.0  5.0  0.0
# 102                 1.0    0.51                  2.700  99.990  2.0  7.0  0.0
#
# ...

# %%
X_test
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)  Purity     Y    M  \
# 18                  1.0    0.30                   7.00   99.91  2.00  0.0
# 45                  0.9    1.09                   1.68   99.99  2.00  0.0
# 47                  0.1    0.30                   1.00   99.00  2.00  5.0
# 89                  1.0    0.51                   2.70   99.99  2.00  3.0
# 4                   1.0    0.28                   8.50   99.99  2.00  5.0
# 40                  1.0    0.30                   7.00   99.91  2.00  0.0
# 62                  0.9    0.30                   1.00   99.90  2.00  5.0
# 107                 1.0    0.51                   2.70   99.99  1.50  5.0
# 31                  0.1    0.30                   1.00   99.00  5.00  5.0
# 55                  1.0    0.30                   1.00   99.00  5.00  5.0
# 53                  1.0    0.30                   1.00   99.00  1.00  5.0
# 119                 1.0    0.51                   2.70   99.99  5.00  5.0
# ...

# %%
# X_test.drop(12, inplace=True)
# X_test.drop(42, inplace=True)
# X_test.drop(44, inplace=True)
# X_test.drop(45, inplace=True)
# # y_test.drop(44, inplace=True)
# y_test.drop(45, inplace=True)

# %%
df['Thermal Conductivity(W/mK)'][12]
# Out:
# 88.8

# %%
train_without = df.drop(['Thermal Conductivity(W/mK)'], axis = 1)
train_without.loc[44]
# Out:
# Sintering Pressure                0.90
# Oxygen                            1.09
# Particle size(d50 um)             1.68
# Purity                           99.99
# Y                                 2.00
# M                                 0.00
# Al                                0.20
# N2/N2:H2 = 1/0                    1.00
# Nitriding Temperature(degC)    1400.00
# Nitriding Time(h)                 8.00
# Sintering Temperature(degC)    1900.00
# Sintering Time(h)                 6.00
# Name: 44, dtype: float64

# %%
# y_train[12]=df['Thermal Conductivity(W/mK)'][12]
# y_train[42]=df['Thermal Conductivity(W/mK)'][42]
# y_train[44]=df['Thermal Conductivity(W/mK)'][44]
# y_train[45]=df['Thermal Conductivity(W/mK)'][45]
# X_train[44]=train_without.loc[44]
# X_train[45]=train_without.loc[45]

# %%
X_train
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)  Purity    Y    M   Al  \
# 0                   1.0    0.28                  8.500  99.990  2.0  5.0  0.0
# 26                  0.9    0.30                  1.676  99.999  2.0  0.0  0.0
# 44                  0.9    1.09                  1.680  99.990  2.0  0.0  0.2
# 66                  0.9    0.30                  1.000  99.900  1.0  3.0  0.0
# 98                  1.0    0.51                  2.700  99.990  2.0  3.0  0.0
# ..                  ...     ...                    ...     ...  ...  ...  ...
# 106                 1.0    0.51                  2.700  99.990  1.0  5.0  0.0
# 14                  0.9    0.28                  8.500  99.990  2.0  5.0  0.0
# 92                  1.0    0.51                  2.700  99.990  2.0  6.0  0.0
# 51                  1.0    0.30                  1.000  99.000  5.0  5.0  0.0
# 102                 1.0    0.51                  2.700  99.990  2.0  7.0  0.0
#
# ...

# %%
# y_train = y_train.drop(80)
# y_train = y_train.drop(81)
# X_train.drop(80, inplace=True)
# X_train.drop(81, inplace=True)

# %%
# y_test = y_test.drop(12)
# y_test = y_test.drop(42)
# y_test = y_test.drop(44)
# y_test = y_test.drop(45)

# %%
df.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<AxesSubplot: title={'center': 'Thermal Conductivity(W/mK)'}>,
#         <AxesSubplot: title={'center': 'Sintering Pressure'}>,
#         <AxesSubplot: title={'center': 'Oxygen'}>,
#         <AxesSubplot: title={'center': 'Particle size(d50 um)'}>],
#        [<AxesSubplot: title={'center': 'Purity'}>,
#         <AxesSubplot: title={'center': 'Y'}>,
#         <AxesSubplot: title={'center': 'M'}>,
#         <AxesSubplot: title={'center': 'Al'}>],
#        [<AxesSubplot: title={'center': 'N2/N2:H2 = 1/0'}>,
#         <AxesSubplot: title={'center': 'Nitriding Temperature(degC)'}>,
#         <AxesSubplot: title={'center': 'Nitriding Time(h)'}>,
#         <AxesSubplot: title={'center': 'Sintering Temperature(degC)'}>],
#        [<AxesSubplot: title={'center': 'Sintering Time(h)'}>,
#         <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %%
df['Thermal Conductivity(W/mK)'].hist(figsize=(5, 5), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# <AxesSubplot: >

# %%
len(y_train), len(X_train), len(X_test), len(y_test)
# Out:
# (103, 103, 19, 19)

# %%
X_train
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)  Purity    Y    M   Al  \
# 0                   1.0    0.28                  8.500  99.990  2.0  5.0  0.0
# 26                  0.9    0.30                  1.676  99.999  2.0  0.0  0.0
# 44                  0.9    1.09                  1.680  99.990  2.0  0.0  0.2
# 66                  0.9    0.30                  1.000  99.900  1.0  3.0  0.0
# 98                  1.0    0.51                  2.700  99.990  2.0  3.0  0.0
# ..                  ...     ...                    ...     ...  ...  ...  ...
# 106                 1.0    0.51                  2.700  99.990  1.0  5.0  0.0
# 14                  0.9    0.28                  8.500  99.990  2.0  5.0  0.0
# 92                  1.0    0.51                  2.700  99.990  2.0  6.0  0.0
# 51                  1.0    0.30                  1.000  99.000  5.0  5.0  0.0
# 102                 1.0    0.51                  2.700  99.990  2.0  7.0  0.0
#
# ...

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

# my_model = XGBRegressor(max_depth = 2)
# # Add silent=True to avoid printing out updates with each cycle
# my_model.fit(X_train, y_train, verbose=True)

# Define the hyperparameter grid
param_grid = {
        'min_child_weight': [1, 3, 5, 8, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [2, 3, 4, 5, 10, 15]
        }
# param_grid = {'gamma': [0.5, 1, 1.5, 2, 5]}
# Create the XGBoost model object
xgb_model = XGBRegressor() 

# Create the GridSearchCV object
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')

# Fit the GridSearchCV object to the training data
results = grid_search.fit(X_train, y_train)
results
# Print the best set of hyperparameters and the corresponding score
print("Best set of hyperparameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
grid_search.cv_results_['mean_test_score']
# Out:
# Best set of hyperparameters:  {'colsample_bytree': 0.6, 'gamma': 2, 'max_depth': 15, 'min_child_weight': 1, 'subsample': 1.0}
# Best score:  0.7476018754281901
# array([0.6843101 , 0.70313295, 0.67316224, ..., 0.63722645, 0.63731564,
#        0.63194842])

# %%
max(grid_search.cv_results_['mean_test_score'])
# Out:
# 0.7476018754281901

# %%
xgb_model.fit(X_train, y_train)
training_feature_imp = xgb_model.feature_importances_

# %%
import pickle
pickle_out = open('xgboost_srbsn.pkl', 'wb')
saved_model = pickle.dump(xgb_model, pickle_out)
pickle_out.close()

# %%
xgb_model.fit(X,y)
all_feat_imp = xgb_model.feature_importances_

# %%
all_feat_imp
# Out:
# array([0.1781343 , 0.02713417, 0.11348939, 0.30285385, 0.08097108,
#        0.01123799, 0.00789086, 0.00906452, 0.00150707, 0.0067577 ,
#        0.03551555, 0.22544344], dtype=float32)

# %%
X.columns
# Out:
# Index(['Sintering Pressure', 'Oxygen', 'Particle size(d50 um)', 'Purity', 'Y',
#        'M', 'Al', 'N2/N2:H2 = 1/0', 'Nitriding Temperature(degC)',
#        'Nitriding Time(h)', 'Sintering Temperature(degC)',
#        'Sintering Time(h)'],
#       dtype='object')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example feature names (replace with actual column names)
feature_names = ['Sintering Pressure', 'Oxygen', 'Particle size(d50 um)', 'Purity', 'Y',
       'Yb', 'M', 'Mn', 'L', 'Eu', 'Al', 'N2/N2:H2 = 1/0',
       'Nitriding Temperature(degC)', 'Nitriding Time(h)',
       'Sintering Temperature(degC)', 'Sintering Time(h)']

# Example feature importance values (replace with your actual XGBoost output)
# feature_importance = np.array([0.15, 0.08, 0.12, 0.25, 0.10, 0.05, 0.18, 0.07])
# feature_importance = all_feat_imp
feature_importance = np.array([0.19270512, 0.02776487, 0.11890846, 0.24759862, 0.08532259,
       0.0059581 , 0.01187831, 0.01448492, 0.00264795, 0.00073243,
       0.0097688 , 0.0010021 , 0.0018001 , 0.01442064, 0.03653036,
       0.22847664])

# Sort features by importance in descending order
sorted_indices = np.argsort(feature_importance)[::-1]  # Get sorted indices in descending order
sorted_features = np.array(feature_names)[sorted_indices]
sorted_importance = feature_importance[sorted_indices]

# Create figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

# Plot horizontal bar chart
ax.barh(sorted_features, sorted_importance, color='skyblue', edgecolor='black')

# Invert y-axis so the most important feature is on top
ax.invert_yaxis()

# Add labels and title
ax.set_xlabel('Feature Importance Score')
ax.set_ylabel('Features')
ax.set_title('XGBoost Feature Importance')

# Add major and minor grid lines
ax.grid(True, which='major', linestyle='--', linewidth=0.5)
ax.grid(True, which='minor', linestyle=':', linewidth=0.3)

# Add ticks
ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True))
ax.xaxis.set_minor_locator(plt.AutoLocator())

# Enclose chart in a box
for spine in ax.spines.values():
    spine.set_visible(True)

# Show plot
# plt.show()
plt.savefig("feature_importance.png", bbox_inches='tight', dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt
import textwrap

# New feature names mapped correctly to the old feature importance values
feature_names = [
    'Silicon Purity', 'Sintering Pressure', 'Sintering Time', 'Particle Size',
    r'Y$_2$O$_3$', 'Oxygen', 'MgO', 'Post Sintering Temperature',
    'Nitriding Time', 'Aluminium', r'Nitriding Temperature', r'N$_2$/N$_2$:H$_2$'
]

# Feature importance values (mapped from original values)
feature_importance = np.array([0.2476, 0.1927, 0.2285, 0.1189, 0.0853, 
                               0.0278, 0.0119, 0.0365, 0.0144, 0.0098, 
                               0.0018, 0.0010])

# Sort features by importance in descending order
sorted_indices = np.argsort(feature_importance)[::-1]
sorted_features = np.array(feature_names)[sorted_indices]
sorted_importance = feature_importance[sorted_indices]

# Wrap feature names to prevent overflow
wrapped_features = [textwrap.fill(f, width=18) for f in sorted_features]  # Adjust width as needed

# Create figure and axis
fig, ax = plt.subplots(figsize=(9, 7))  # Keep width wide for readability

# Plot horizontal bar chart
ax.barh(wrapped_features, sorted_importance, color='#0B2D5B', edgecolor='black')

# Invert y-axis so the most important feature is on top
ax.invert_yaxis()

# Set labels
ax.set_xlabel('Feature Importance', fontsize=14, fontname='Times New Roman', fontweight='bold')
ax.set_ylabel(' ', fontsize=14, fontname='Times New Roman')  # Hiding "Features" label
ax.set_xticks(np.arange(0, 0.35, 0.05))  # Set ticks similar to the image
ax.tick_params(axis='both', labelsize=12)

# Left-align y-axis labels
ax.set_yticklabels(wrapped_features, fontname='Times New Roman', fontsize=12, fontweight='bold', ha='left')
ax.yaxis.set_tick_params(pad=120)  # Push labels further left

# **REMOVED extra space**
ax.margins(y=0)  # No extra margins at the top & bottom

# Grid styling (only major grid lines)
ax.grid(True, which='major', linestyle='--', linewidth=0.5, alpha=0.7)
ax.grid(False, which='minor')

# Enclose chart in a black box
for spine in ax.spines.values():
    spine.set_color('black')
    spine.set_linewidth(1.2)

# **Fix layout to remove unwanted spacing**
plt.tight_layout(rect=[0, 0, 1, 1])  # Ensures everything fits neatly without extra space

# Show the plot
# plt.show()

plt.xticks(fontsize=12, fontweight='bold')  # Bold x-axis values
plt.yticks(fontsize=12, fontweight='bold')  # Bold y-axis values
# Show the plot
plt.savefig("ffff.tiff", bbox_inches='tight', dpi=1200)
# Out:
# /tmp/ipykernel_102531/3016092512.py:41: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(wrapped_features, fontname='Times New Roman', fontsize=12, fontweight='bold', ha='left')

# %%
import matplotlib.font_manager as fm
for font in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
    if 'times' in font.lower():
        print(font)
# Out:
# /usr/share/fonts/truetype/msttcorefonts/Times_New_Roman.ttf
# /usr/share/fonts/truetype/msttcorefonts/times.ttf
# /usr/share/fonts/truetype/msttcorefonts/Times_New_Roman_Italic.ttf
# /usr/share/fonts/truetype/msttcorefonts/timesbi.ttf
# /usr/share/fonts/truetype/msttcorefonts/Times_New_Roman_Bold_Italic.ttf
# /usr/share/fonts/truetype/msttcorefonts/Times_New_Roman_Bold.ttf
# /usr/share/fonts/truetype/msttcorefonts/timesbd.ttf
# /usr/share/fonts/truetype/msttcorefonts/timesi.ttf

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# Replace with the actual path to Times New Roman font on your system
font_path = "/home/chiru/Desktop/Codin/srbsn'/Times New Roman.ttf"  # Linux
# font_path = "C:/Windows/Fonts/times.ttf"  # Windows
# font_path = "/System/Library/Fonts/Supplemental/Times New Roman.ttf"  # Mac

times_new_roman = fm.FontProperties(fname=font_path)
plt.rcParams["font.family"] = times_new_roman.get_name()
times_new_roman

# %%
plt.plot(all_feat_imp)

# %%
import matplotlib.pyplot as plt

# Example 1-dimensional array
data = all_feat_imp

# Indices for the X-axis
x = range(0,16)

# Create the bar plot
plt.bar(x, data)

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Bar Graph of 1-Dimensional Array')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 10
#       7 x = range(0,16)
#       9 # Create the bar plot
# ---> 10 plt.bar(x, data)
#      12 # Add labels and title
#      13 plt.xlabel('Index')
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2375, in bar(x, height, width, bottom, align, data, **kwargs)
#    2371 @_copy_docstring_and_deprecators(Axes.bar)
#    2372 def bar(
#    2373         x, height, width=0.8, bottom=None, *, align='center',
#    2374         data=None, **kwargs):
# -> 2375     return gca().bar(
#    2376         x, height, width=width, bottom=bottom, align=align,
#    2377         **({"data": data} if data is not None else {}), **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/__init__.py:1437, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1434 @functools.wraps(func)
# ...

# %%
file_path = r"/home/chiru/Desktop/Codin/srbsn'/xgboost_srbsn.pkl"

with open(file_path , 'rb') as f:
    loaded_model = pickle.load(f)

# %%
loaded_model.get_booster().get_score()
# Out:
# {'Sintering Pressure': 111.0,
#  'Oxygen': 299.0,
#  'Particle size(d50 um)': 185.0,
#  'Purity': 46.0,
#  'Y': 366.0,
#  'M': 292.0,
#  'Al': 80.0,
#  'N2/N2:H2 = 1/0': 8.0,
#  'Nitriding Temperature(degC)': 56.0,
#  'Nitriding Time(h)': 82.0,
#  'Sintering Temperature(degC)': 182.0,
#  'Sintering Time(h)': 324.0}

# %%
from sklearn.model_selection import StratifiedKFold
# XGBoost on Otto dataset, Tune max_depth
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot

max_depth = [3,4,5]
param_grid = dict(max_depth=max_depth)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
 print("%f (%f) with: %r" % (mean, stdev, param))
# plot

plt.figure()
pyplot.errorbar(max_depth, means, yerr=stds)
pyplot.title("XGBoost max_depth vs R2")
pyplot.xlabel('max_depth')
pyplot.ylabel('R2')
pyplot.savefig('max_depth.tif', dpi =80)
# Out:
# Best: 0.697549 using {'max_depth': 3}
# 0.697549 (0.162201) with: {'max_depth': 3}
# 0.661562 (0.179304) with: {'max_depth': 4}
# 0.672741 (0.200490) with: {'max_depth': 5}

# %%
from sklearn.model_selection import StratifiedKFold
# XGBoost on Otto dataset, Tune max_depth
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot

colsample_bytree = [0.6, 0.8, 1.0]
param_grid = dict(colsample_bytree=colsample_bytree)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
 print("%f (%f) with: %r" % (mean, stdev, param))
# plot

plt.figure()
pyplot.errorbar(colsample_bytree, means, yerr=stds)
pyplot.title("XGBoost colsample_bytree vs R2")
pyplot.xlabel('colsample_bytree')
pyplot.ylabel('R2')
pyplot.savefig('colsample_bytree.png')
# Out:
# Best: 0.712216 using {'colsample_bytree': 0.6}
# 0.712216 (0.178609) with: {'colsample_bytree': 0.6}
# 0.707067 (0.159577) with: {'colsample_bytree': 0.8}
# 0.658321 (0.211200) with: {'colsample_bytree': 1.0}

# %%
len(X_train)
# Out:
# 103

# %%
from sklearn.model_selection import StratifiedKFold
# XGBoost on Otto dataset, Tune max_depth
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot

subsample = [0.6, 0.8, 1.0]
param_grid = dict(subsample=subsample)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
 print("%f (%f) with: %r" % (mean, stdev, param))
# plot
plt.figure()
pyplot.errorbar(subsample, means, yerr=stds)
pyplot.title("XGBoost subsample vs R2")
pyplot.xlabel('subsample')
pyplot.ylabel('R2')
pyplot.savefig('subsample.png')
# Out:
# Best: 0.668877 using {'subsample': 0.6}
# 0.668877 (0.185563) with: {'subsample': 0.6}
# 0.633243 (0.212694) with: {'subsample': 0.8}
# 0.658321 (0.211200) with: {'subsample': 1.0}

# %%
from sklearn.model_selection import StratifiedKFold
# XGBoost on Otto dataset, Tune max_depth
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot

gamma = [0.5, 1, 1.5, 2, 5]
param_grid = dict(gamma=gamma)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
 print("%f (%f) with: %r" % (mean, stdev, param))
# plot

plt.figure()
pyplot.errorbar(gamma, means, yerr=stds)
pyplot.title("XGBoost gamma vs R2")
pyplot.xlabel('gamma')
pyplot.ylabel('R2')
pyplot.savefig('gamma.png')
# Out:
# Best: 0.669997 using {'gamma': 1.5}
# 0.666363 (0.196479) with: {'gamma': 0.5}
# 0.669977 (0.192613) with: {'gamma': 1}
# 0.669997 (0.197130) with: {'gamma': 1.5}
# 0.668739 (0.200827) with: {'gamma': 2}
# 0.658920 (0.200478) with: {'gamma': 5}

# %%
from sklearn.model_selection import StratifiedKFold
# XGBoost on Otto dataset, Tune max_depth
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot

min_child_weight = [1, 5, 10]
param_grid = dict(min_child_weight=min_child_weight)
# kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=7)
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2')
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
 print("%f (%f) with: %r" % (mean, stdev, param))
# plot

plt.figure()
pyplot.errorbar(min_child_weight, means, yerr=stds)
pyplot.title("XGBoost min_child_weight vs R2")
pyplot.xlabel('min_child_weight')
pyplot.ylabel('R2')
pyplot.savefig('min_child_weight.png')
# Out:
# Best: 0.658741 using {'min_child_weight': 5}
# 0.658321 (0.211200) with: {'min_child_weight': 1}
# 0.658741 (0.193171) with: {'min_child_weight': 5}
# 0.628603 (0.229926) with: {'min_child_weight': 10}

# %%
grid_search.best_params_
# Out:
# {'min_child_weight': 5}

# %%
# grid_search.best_params_
# {'colsample_bytree': 0.6, 'gamma': 5, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8}
#  {'colsample_bytree': 0.6, 'gamma': 2, 'max_depth': 15, 'min_child_weight': 1, 'subsample': 1.0}
my_model = XGBRegressor(colsample_bytree = 0.8, gamma = 2, max_depth = 5, min_child_weight = 1, subsample = 0.6)
# Add silent=True to avoid printing out updates with each cycle{'colsample_bytree': 1.0, 'gamma': 1, 'max_depth': 2, 'min_child_weight': 1, 'subsample': 1.0}
my_model.fit(X_train, y_train, verbose=True)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=2, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=15, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# my_model.get_score(importance_type='gain')

# %%
# def get_xgb_imp(xgb, feat_names):
#     from numpy import array
#     imp_vals = xgb.booster().get_fscore()
#     imp_dict = {feat_names[i]:float(imp_vals.get('f'+str(i),0.)) for i in range(len(feat_names))}
#     total = array(imp_dict.values()).sum()
#     return {k:v/total for k,v in imp_dict.items()}

# feat_names = [['Sintering Pressure', 'Oxygen', 'Particle size(d50 um)', 'Purity', 'Y',
#        'Yb', 'M', 'Mn', 'L', 'Eu', 'Al', 'N2/N2:H2 = 1/0',
#        'Nitriding Temperature(degC)', 'Nitriding Time(h)',
#        'Sintering Temperature(degC)', 'Sintering Time(h)']]
# get_xgb_imp(my_model,feat_names)

# %%
# make predictions
predictions = my_model.predict(X_test)

# from sklearn.metrics import mean_absolute_error
# print("Mean Absolute Error : " + str(mean_absolute_error(predictions, X_test)))
len(predictions)
# Out:
# 19

# %%
# # grid search
# model = XGBClassifier()
# n_estimators = range(50, 400, 50)
# param_grid = dict(n_estimators=n_estimators)
# kfold = StratifiedKFold(n_splits scoring="neg_log_loss", n_jobs=-1, cv=kfold)
# result = grid_search.fit(X, label_encoded_y)

# %%
print(results)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
# ...

# %%
# # XGBoost on Otto dataset, Tune n_estimators
# from pandas import read_csv
# from xgboost import XGBClassifier
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import StratifiedKFold
# from sklearn.preprocessing import LabelEncoder
# import matplotlib
# matplotlib.use('Agg')
# from matplotlib import pyplot

# # summarize results
# print("Best: %f using %s" % (results.best_score_, results.best_params_))


# print(mean , 'djhgffghj')

# %%
test_df = pd.DataFrame(y_test)
test_df['Actual'] = y_test[0:]
test_df.drop("Thermal Conductivity(W/mK)", axis = 1, inplace=True)
test_df
# Out:
#      Actual
# 18    111.0
# 45     58.0
# 47     63.0
# 89    124.0
# 4      99.0
# 40    135.0
# 62     77.0
# 107   121.0
# 31     66.7
# 55     84.0
# 53     89.0
# 119   136.0
# 10    115.0
# 90    126.0
# 109   128.0
# 11    133.0
# 76    110.3
# 56    107.0
# 115   155.0

# %%
test_df['Predictions'] = predictions
test_df['Predictions - Actual/actual'] = ((test_df['Predictions']-test_df['Actual'])/test_df['Actual'])*100
test_df
# Out:
#      Actual  Predictions  Predictions - Actual/actual
# 18    111.0   110.499626                    -0.450787
# 45     58.0    67.901619                    17.071757
# 47     63.0    63.656769                     1.042490
# 89    124.0   125.503418                     1.212434
# 4      99.0   103.686470                     4.733808
# 40    135.0   132.192276                    -2.079796
# 62     77.0    72.341629                    -6.049832
# 107   121.0   114.179657                    -5.636647
# 31     66.7    69.095039                     3.590764
# 55     84.0    89.075607                     6.042390
# 53     89.0    89.486130                     0.546213
# 119   136.0   134.815872                    -0.870682
# 10    115.0   101.666023                   -11.594762
# 90    126.0   125.761047                    -0.189645
# 109   128.0   124.618980                    -2.641422
# 11    133.0   130.698532                    -1.730427
# ...

# %%
(predictions*tc_std)+tc_mean
# Out:
# array([2983.5261, 1872.8622, 1762.1857, 3374.7222, 2805.8857, 3549.1218,
#        1988.6272, 3079.476 , 1903.9784, 2424.9348, 2435.6384, 3617.527 ,
#        2753.2065, 3381.4395, 3351.662 , 3510.175 , 2599.8018, 2806.298 ,
#        3883.9783], dtype=float32)

# %%
ytest2 = y_test
pred2 = predictions
v = ytest2-pred2
v = pd.DataFrame(v)
# v = v.drop(18)

# %%
import numpy as np
import tensorflow as tf
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[121], line 2
#       1 import numpy as np
# ----> 2 import tensorflow as tf
#       3 import math
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
MS = np.square(v).mean()
rs = math.sqrt(MS)
rs
# Out:
# /tmp/ipykernel_102531/195823076.py:2: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rs = math.sqrt(MS)
# 6.273153119478532

# %%
X_test
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)  Purity     Y    M  \
# 18                  1.0    0.30                   7.00   99.91  2.00  0.0
# 45                  0.9    1.09                   1.68   99.99  2.00  0.0
# 47                  0.1    0.30                   1.00   99.00  2.00  5.0
# 89                  1.0    0.51                   2.70   99.99  2.00  3.0
# 4                   1.0    0.28                   8.50   99.99  2.00  5.0
# 40                  1.0    0.30                   7.00   99.91  2.00  0.0
# 62                  0.9    0.30                   1.00   99.90  2.00  5.0
# 107                 1.0    0.51                   2.70   99.99  1.50  5.0
# 31                  0.1    0.30                   1.00   99.00  5.00  5.0
# 55                  1.0    0.30                   1.00   99.00  5.00  5.0
# 53                  1.0    0.30                   1.00   99.00  1.00  5.0
# 119                 1.0    0.51                   2.70   99.99  5.00  5.0
# ...

# %%
columns = X_test.columns
columns
# Out:
# Index(['Sintering Pressure', 'Oxygen', 'Particle size(d50 um)', 'Purity', 'Y',
#        'M', 'Al', 'N2/N2:H2 = 1/0', 'Nitriding Temperature(degC)',
#        'Nitriding Time(h)', 'Sintering Temperature(degC)',
#        'Sintering Time(h)'],
#       dtype='object')

# %%
(y_test)
# Out:
# 18     111.0
# 45      58.0
# 47      63.0
# 89     124.0
# 4       99.0
# 40     135.0
# 62      77.0
# 107    121.0
# 31      66.7
# 55      84.0
# 53      89.0
# 119    136.0
# 10     115.0
# 90     126.0
# 109    128.0
# 11     133.0
# 76     110.3
# 56     107.0
# 115    155.0
# Name: Thermal Conductivity(W/mK), dtype: float64

# %%
import numpy as np
import math

MSE = np.square(np.subtract(predictions, y_test)).mean()
rsme = math.sqrt(MSE)
rsme
# Out:
# 6.273153119478532

# %%
peri = my_model.predict(X_train)
# (peri*tc_std)+tc_mean
peri
# Out:
# array([103.68647 ,  82.35532 ,  67.90162 ,  73.657616, 155.56282 ,
#        135.69566 ,  83.93035 ,  99.28575 , 107.40489 ,  88.76502 ,
#        150.18593 ,  88.50272 , 112.07671 ,  96.675285, 105.987465,
#        150.18593 , 123.88199 , 111.11259 ,  83.194336,  87.77998 ,
#         73.657616, 103.25922 , 101.57658 , 139.74359 ,  63.97603 ,
#         86.19023 ,  86.95627 , 106.055504, 103.68647 ,  73.657616,
#         81.34754 , 119.85935 ,  80.02792 , 101.57658 , 112.020485,
#         72.34163 , 101.57658 , 111.11259 ,  74.34573 ,  74.24944 ,
#         57.21151 ,  88.69059 , 103.86364 ,  93.22943 , 119.85935 ,
#        154.15176 , 126.07115 ,  99.4083  , 100.69662 , 111.467865,
#        103.68647 , 119.85935 , 110.499626, 100.84006 ,  69.09504 ,
#         95.782394,  58.97093 , 148.9641  ,  94.04334 ,  83.56088 ,
#        106.77527 ,  62.42837 ,  69.56492 ,  72.34163 , 143.72823 ,
#        103.86364 , 117.69668 ,  88.067276, 108.625755,  63.623062,
# ...

# %%
len(peri)
# Out:
# 103

# %%
MSE2 = np.square(np.subtract(peri, y_train)).mean()
rsme2 = math.sqrt(MSE2)

# %%
rsme2
# Out:
# 3.2269849262170753

# %%
f = pd.DataFrame(y_train)
f
# Out:
#      Thermal Conductivity(W/mK)
# 0                         102.0
# 26                         82.0
# 44                         66.2
# 66                         77.0
# 98                        155.0
# ..                          ...
# 106                       114.0
# 14                        101.2
# 92                        121.0
# 51                         76.0
# 102                       144.0
#
# [103 rows x 1 columns]

# %%
f['Predictions'] = peri
f
# Out:
#      Thermal Conductivity(W/mK)  Predictions
# 0                         102.0   103.686470
# 26                         82.0    82.355324
# 44                         66.2    67.901619
# 66                         77.0    73.657616
# 98                        155.0   155.562820
# ..                          ...          ...
# 106                       114.0   114.179657
# 14                        101.2   101.726555
# 92                        121.0   120.783447
# 51                         76.0    75.632301
# 102                       144.0   144.417770
#
# [103 rows x 2 columns]

# %%
for_checking = pd.DataFrame(y_train)
for_checking
# Out:
#      Thermal Conductivity(W/mK)
# 0                         102.0
# 26                         82.0
# 44                         66.2
# 66                         77.0
# 98                        155.0
# ..                          ...
# 106                       114.0
# 14                        101.2
# 92                        121.0
# 51                         76.0
# 102                       144.0
#
# [103 rows x 1 columns]

# %%
for_checking['Predicted by model'] = peri
for_checking
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model
# 0                         102.0          103.686470
# 26                         82.0           82.355324
# 44                         66.2           67.901619
# 66                         77.0           73.657616
# 98                        155.0          155.562820
# ..                          ...                 ...
# 106                       114.0          114.179657
# 14                        101.2          101.726555
# 92                        121.0          120.783447
# 51                         76.0           75.632301
# 102                       144.0          144.417770
#
# [103 rows x 2 columns]

# %%
import scipy

slope_train, intercept_train, r_value_train, p_value_train, std_err_train = scipy.stats.linregress(for_checking['Thermal Conductivity(W/mK)'], for_checking['Predicted by model'])
r_value_train**2
# Out:
# 0.9843555399643583

# %%
r_value_train
# Out:
# 0.9921469346645981

# %%
f.to_csv("Origin_train_data.csv")

# %%
f.plot.scatter(x='Predictions', y='Thermal Conductivity(W/mK)', title= "Represents training set deviation in values")
plt.text(.01, .99, 'R² = {}'.format(r_value_train**2), ha='left', va='top', transform=ax.transAxes)
plt.savefig('train_r2.png')

# %%
from matplotlib.pyplot import scatter
f.scatter(x='Predictions', y='Thermal Conductivity(W/mK)', title= "Represents training set deviation in values")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_102531/1585704949.py in ?()
#       1 from matplotlib.pyplot import scatter
# ----> 2 f.scatter(x='Predictions', y='Thermal Conductivity(W/mK)', title= "Represents training set deviation in values")
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'

# %%
predictions
# Out:
# array([110.499626,  67.90162 ,  63.65677 , 125.50342 , 103.68647 ,
#        132.19228 ,  72.34163 , 114.17966 ,  69.09504 ,  89.07561 ,
#         89.48613 , 134.81587 , 101.66602 , 125.76105 , 124.61898 ,
#        130.69853 ,  95.782394, 103.70228 , 145.03525 ], dtype=float32)

# %%
(((y_test-predictions)/y_test).mean())*100
# Out:
# 1.0356277639061062

# %%
y_test-predictions
# Out:
# 18      0.500374
# 45     -9.901619
# 47     -0.656769
# 89     -1.503418
# 4      -4.686470
# 40      2.807724
# 62      4.658371
# 107     6.820343
# 31     -2.395039
# 55     -5.075607
# 53     -0.486130
# 119     1.184128
# 10     13.333977
# 90      0.238953
# 109     3.381020
# 11      2.301468
# 76     14.517606
# 56      3.297722
# 115     9.964752
# Name: Thermal Conductivity(W/mK), dtype: float64

# %%
for_checking['Percentage Error'] = ((for_checking['Predicted by model']-for_checking['Thermal Conductivity(W/mK)'])/for_checking['Thermal Conductivity(W/mK)'])*100

# %%
for_checking.sort_index()
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error
# 0                         102.0          103.686470          1.653402
# 1                         102.4          103.686470          1.256318
# 2                         103.4          103.686470          0.277050
# 3                         101.3          103.686470          2.355844
# 5                         108.4          103.686470         -4.348275
# ..                          ...                 ...               ...
# 116                       154.0          150.185928         -2.476670
# 117                       151.0          150.185928         -0.539120
# 118                       143.0          143.728226          0.509249
# 120                        86.0           86.956268          1.111940
# 121                        50.1           51.500080          2.794571
#
# [103 rows x 3 columns]

# %%
for_checking_test = pd.DataFrame(y_test)
for_checking_test
# Out:
#      Thermal Conductivity(W/mK)
# 18                        111.0
# 45                         58.0
# 47                         63.0
# 89                        124.0
# 4                          99.0
# 40                        135.0
# 62                         77.0
# 107                       121.0
# 31                         66.7
# 55                         84.0
# 53                         89.0
# 119                       136.0
# 10                        115.0
# 90                        126.0
# 109                       128.0
# 11                        133.0
# 76                        110.3
# 56                        107.0
# 115                       155.0

# %%
test_df.columns = ['Thermal Conductivity(W/mK)', 'Predicted by model', 'Percentage Error']
test_df
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error
# 18                        111.0          110.499626         -0.450787
# 45                         58.0           67.901619         17.071757
# 47                         63.0           63.656769          1.042490
# 89                        124.0          125.503418          1.212434
# 4                          99.0          103.686470          4.733808
# 40                        135.0          132.192276         -2.079796
# 62                         77.0           72.341629         -6.049832
# 107                       121.0          114.179657         -5.636647
# 31                         66.7           69.095039          3.590764
# 55                         84.0           89.075607          6.042390
# 53                         89.0           89.486130          0.546213
# 119                       136.0          134.815872         -0.870682
# ...

# %%
len(test_df)
# Out:
# 19

# %%
slope_test, intercept_test, r_value_test, p_value_test, std_err_test = scipy.stats.linregress(test_df['Thermal Conductivity(W/mK)'], predictions)
r_value_test**2
# Out:
# 0.9565667396747872

# %%
test_df.plot.scatter(x='Predicted by model', y='Thermal Conductivity(W/mK)', title= "Represents test deviation in values")
plt.text(.01, .99, 'R² = {}'.format(r_value_test**2), ha='left', va='top', transform=ax.transAxes)
plt.savefig('test_r2.png')

# %%
test_df.to_csv("Origin_test.csv")

# %%
new_dataframe = pd.concat([for_checking, test_df])
new_dataframe
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error
# 0                         102.0          103.625244          1.593377
# 26                         82.0           82.891426          1.087105
# 44                         66.2           67.716003          2.290035
# 66                         77.0           73.451431         -4.608531
# 98                        155.0          154.898438         -0.065524
# ..                          ...                 ...               ...
# 109                       128.0          119.535789         -6.612664
# 11                        133.0          137.417816          3.321666
# 76                        110.3           95.645737        -13.285823
# 56                        107.0          103.261932         -3.493521
# 115                       155.0          146.978836         -5.174944
#
# [122 rows x 3 columns]

# %%
import scipy
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(newer['Thermal Conductivity(W/mK)'], newer['Predicted by model'])
r_value**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 2
#       1 import scipy
# ----> 2 slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(newer['Thermal Conductivity(W/mK)'], newer['Predicted by model'])
#       3 r_value**2
#
# NameError: name 'newer' is not defined

# %%
new_dataframe.plot.scatter(x='Predicted by model', y='Thermal Conductivity(W/mK)', title= "Represents all deviation in values")
plt.text(.01, .99, 'R² = {}'.format(r_value**2), ha='left', va='top', transform=ax.transAxes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 2
#       1 new_dataframe.plot.scatter(x='Predicted by model', y='Thermal Conductivity(W/mK)', title= "Represents all deviation in values")
# ----> 2 plt.text(.01, .99, 'R² = {}'.format(r_value**2), ha='left', va='top', transform=ax.transAxes)
#
# NameError: name 'r_value' is not defined

# %%
new_dataframe = new_dataframe.sort_index()

# %%
new_dataframe.to_csv("Checking2.csv")

# %%
for_checking['TT'] = 'Train'
for_checking
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error     TT
# 0                         102.0          103.625244          1.593377  Train
# 26                         82.0           82.891426          1.087105  Train
# 44                         66.2           67.716003          2.290035  Train
# 66                         77.0           73.451431         -4.608531  Train
# 98                        155.0          154.898438         -0.065524  Train
# ..                          ...                 ...               ...    ...
# 106                       114.0          113.811440         -0.165404  Train
# 14                        101.2          100.738914         -0.455618  Train
# 92                        121.0          119.359955         -1.355409  Train
# 51                         76.0           75.949631         -0.066275  Train
# 102                       144.0          143.222595         -0.539864  Train
#
# [103 rows x 4 columns]

# %%
test_df['TT'] = 'Test'
test_df
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error    TT
# 18                        111.0          112.805054          1.626175  Test
# 45                         58.0           67.716003         16.751730  Test
# 47                         63.0           68.976463          9.486450  Test
# 89                        124.0          123.979057         -0.016889  Test
# 4                          99.0          103.625244          4.671964  Test
# 40                        135.0          131.441284         -2.636086  Test
# 62                         77.0           72.336472         -6.056530  Test
# 107                       121.0          113.811440         -5.940959  Test
# 31                         66.7           67.135727          0.653264  Test
# 55                         84.0           86.970367          3.536152  Test
# 53                         89.0           89.581505          0.653376  Test
# ...

# %%
newer = pd.concat([test_df, for_checking])
newer
# Out:
#      Thermal Conductivity(W/mK)  Predicted by model  Percentage Error     TT
# 18                        111.0          112.805054          1.626175   Test
# 45                         58.0           67.716003         16.751730   Test
# 47                         63.0           68.976463          9.486450   Test
# 89                        124.0          123.979057         -0.016889   Test
# 4                          99.0          103.625244          4.671964   Test
# ..                          ...                 ...               ...    ...
# 106                       114.0          113.811440         -0.165404  Train
# 14                        101.2          100.738914         -0.455618  Train
# 92                        121.0          119.359955         -1.355409  Train
# 51                         76.0           75.949631         -0.066275  Train
# 102                       144.0          143.222595         -0.539864  Train
#
# [122 rows x 4 columns]

# %%
newer = newer.sort_index()

# %%
newer.to_csv('train_test_combined_120_correction.csv')

# %%
import pickle
pickle_out = open('xgboost_srbsn.pkl', 'wb')
saved_model = pickle.dump(my_model, pickle_out)
pickle_out.close()

# %%
X_train
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)  Purity    Y   Yb    M  \
# 0                   1.0    0.28                  8.500  99.990  2.0  0.0  5.0
# 26                  0.9    0.30                  1.676  99.999  2.0  0.0  0.0
# 44                  0.9    1.09                  1.680  99.990  2.0  0.0  0.0
# 66                  0.9    0.30                  1.000  99.900  1.0  0.0  3.0
# 98                  1.0    0.51                  2.700  99.990  2.0  0.0  3.0
# ..                  ...     ...                    ...     ...  ...  ...  ...
# 106                 1.0    0.51                  2.700  99.990  1.0  0.0  5.0
# 14                  0.9    0.28                  8.500  99.990  2.0  0.0  5.0
# 92                  1.0    0.51                  2.700  99.990  2.0  0.0  6.0
# 51                  1.0    0.30                  1.000  99.000  5.0  0.0  5.0
# 102                 1.0    0.51                  2.700  99.990  2.0  0.0  7.0
#
# ...

# %%
X_test
# Out:
#      Sintering Pressure  Oxygen  Particle size(d50 um)  Purity     Y   Yb  \
# 18                  1.0    0.30                   7.00   99.91  2.00  0.0
# 45                  0.9    1.09                   1.68   99.99  2.00  0.0
# 47                  0.1    0.30                   1.00   99.00  2.00  0.0
# 89                  1.0    0.51                   2.70   99.99  2.00  0.0
# 4                   1.0    0.28                   8.50   99.99  2.00  0.0
# 40                  1.0    0.30                   7.00   99.91  2.00  0.0
# 62                  0.9    0.30                   1.00   99.90  2.00  0.0
# 107                 1.0    0.51                   2.70   99.99  1.50  0.0
# 31                  0.1    0.30                   1.00   99.00  5.00  0.0
# 55                  1.0    0.30                   1.00   99.00  5.00  0.0
# 53                  1.0    0.30                   1.00   99.00  1.00  0.0
# 119                 1.0    0.51                   2.70   99.99  5.00  0.0
# ...

# %%
y_train
# Out:
# 0      102.0
# 26      82.0
# 44      66.2
# 66      77.0
# 98     155.0
#        ...
# 106    114.0
# 14     101.2
# 92     121.0
# 51      76.0
# 102    144.0
# Name: Thermal Conductivity(W/mK), Length: 103, dtype: float64

# %%
y_test
# Out:
# 18     111.0
# 45      58.0
# 47      63.0
# 89     124.0
# 4       99.0
# 40     135.0
# 62      77.0
# 107    121.0
# 31      66.7
# 55      84.0
# 53      89.0
# 119    136.0
# 10     115.0
# 90     126.0
# 109    128.0
# 11     133.0
# 76     110.3
# 56     107.0
# 115    155.0
# Name: Thermal Conductivity(W/mK), dtype: float64

# %%
len(y_test), len(predictions), len(y_train), len(peri)
# Out:
# (19, 19, 103, 103)

# %%
r2_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 r2_test
#
# NameError: name 'r2_test' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Example data (Replace these with your actual values)
y_train = y_train  # Measured values for train set
y_train_pred = peri  # Predicted values for train set

y_test = y_test # Measured values for test set|
y_test_pred = predictions  # Predicted values for test set

# # Calculate R^2 scores
from sklearn.metrics import r2_score
r2_test = r2_score(y_test, y_test_pred)
r2_train = r2_score(y_train, y_train_pred)
# r2_test = 0.93
# r2_train = 0.97


# Plot settings
plt.figure(figsize=(7, 6))
sns.set_style("whitegrid")

# Scatter plots for train and test data
plt.scatter(y_train, y_train_pred, color='black', marker='^', label="Train Dataset results XGBOOST")
plt.scatter(y_test, y_test_pred, color='red', marker='o', label="Test Dataset results XGBOOST")

# 45-degree reference line
min_val = min(y_train.min(), y_test.min()) - 5
max_val = max(y_train.max(), y_test.max()) + 5
plt.plot([min_val, max_val], [min_val, max_val], linestyle="dashed", color="red")

# Labels, title, and legend
plt.xlabel("Measured Thermal Conductivity (W/m·K)", fontsize=14, fontname="Times New Roman")
plt.ylabel("Predicted Thermal Conductivity (W/m·K)", fontsize=14, fontname="Times New Roman")
plt.xticks(fontsize=12, fontname="Times New Roman")
plt.yticks(fontsize=12, fontname="Times New Roman")

# Display R^2 values
plt.text(min_val + 5, max_val - 10, f"$R^2$ Train - {r2_train:.2f}", fontsize=14, fontweight='bold', fontname="Times New Roman")
plt.text(min_val + 5, max_val - 15, f"$R^2$ Test - {r2_test:.2f}", fontsize=14, color='red', fontweight='bold', fontname="Times New Roman")

# Add legend
plt.legend(loc="upper left", fontsize=12, prop={"family": "Times New Roman"})

# Show plot
plt.savefig("plot.tiff", bbox_inches='tight', dpi=1200)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Example data (Replace these with your actual values)
y_train = y_train  # Measured values for train set
y_train_pred = peri  # Predicted values for train set

y_test = y_test # Measured values for test set|
y_test_pred = predictions  # Predicted values for test set

# Compute R² values
def calculate_r2(y_true, y_pred):
    slope, intercept, r_value, p_value, std_err = linregress(y_true, y_pred)
    return r_value**2

r2_train = calculate_r2(y_train, y_train_pred)
r2_test = calculate_r2(y_test, y_test_pred)

# from sklearn.metrics import r2_score
# r2_test = r2_score(y_test, y_test_pred)
# r2_train = r2_score(y_train, y_train_pred)

# Create plot
plt.figure(figsize=(8, 7))

# Scatter plots
plt.scatter(y_train, y_train_pred, marker='^', color='black', label="Train Dataset results XGBOOST")
plt.scatter(y_test, y_test_pred, marker='o', color='red', label="Test Dataset results XGBOOST")

# Best-fit line
x_vals = np.linspace(40, 160, 100)
plt.plot(x_vals, x_vals, "r--", linewidth=1)

# R² values placement and styling
plt.text(50, 150, f"$R^2$ Train - {r2_train:.2f}", fontsize=14, fontweight="bold", color="black")
plt.text(50, 140, f"$R^2$ Test - {r2_test:.2f}", fontsize=14, fontweight="bold", color="red", style="italic")

# Labels with bold font
plt.xlabel("Measured Thermal Conductivity (W/m·K)", fontsize=14, fontweight="bold")
plt.ylabel("Predicted Thermal Conductivity (W/m·K)", fontsize=14, fontweight="bold")

# Legend
plt.legend(loc="upper left", fontsize=12)

# Grid and Limits
plt.grid(True, linestyle="--", alpha=0.5)
plt.xlim(40, 160)
plt.ylim(40, 160)

# Show plot
plt.show()
# Out:
# /tmp/ipykernel_102531/1070841766.py:52: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
r2_test
# Out:
# 0.9456602617834202

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Example Data (Replace with your actual data)
# Example data (Replace these with your actual values)
y_train = y_train  # Measured values for train set
y_train_pred = peri  # Predicted values for train set

y_test = y_test # Measured values for test set|
y_test_pred = predictions  # Predicted values for test set

# # Compute R² values
# def calculate_r2(y_true, y_pred):
#     slope, intercept, r_value, p_value, std_err = linregress(y_true, y_pred)
#     return r_value**2

# r2_train = calculate_r2(y_train, y_train_pred)
# r2_test = calculate_r2(y_test, y_test_pred)

from sklearn.metrics import r2_score
r2_test = r2_score(y_test, y_test_pred)
r2_train = r2_score(y_train, y_train_pred)

# Create plot
plt.figure(figsize=(8, 7))

# Scatter plots with correct colors
plt.scatter(y_train, y_train_pred, marker='^', color="#505050", label="Train Dataset results XGBOOST")  # Dark Gray
plt.scatter(y_test, y_test_pred, marker='o', color="#F14040", label="Test Dataset results XGBOOST")  # Red

# Best-fit line
x_vals = np.linspace(40, 160, 100)
plt.plot(x_vals, x_vals, "r--", linewidth=1)

# **Move R² values to prevent overlap**
plt.text(50, 135, f"$R^2$ Train - {r2_train:.2f}", fontsize=14, fontweight="bold", color="black", bbox=dict(facecolor="white", edgecolor="none", boxstyle="round,pad=0.3"))
plt.text(50, 125, f"$R^2$ Test - {r2_test:.2f}", fontsize=14, fontweight="bold", color="#F14040", style="italic", bbox=dict(facecolor="white", edgecolor="none", boxstyle="round,pad=0.3"))

# Labels with bold font
plt.xlabel("Measured Thermal Conductivity (W/m·K)", fontsize=14, fontweight="bold")
plt.ylabel("Predicted Thermal Conductivity (W/m·K)", fontsize=14, fontweight="bold")

# Legend
plt.legend(loc="upper left", fontsize=12)

# Grid and Limits
plt.grid(True, linestyle="--", alpha=0.5)
plt.xlim(40, 160)
plt.ylim(40, 160)
plt.xticks(fontsize=12, fontweight='bold')  # Bold x-axis values
plt.yticks(fontsize=12, fontweight='bold')  # Bold y-axis values

# Show plot
# plt.show()

plt.savefig("plot.jpg", bbox_inches='tight', dpi=1200)

# %%
r2_train, r2_test
# Out:
# (0.9835786889269242, 0.9528556327218355)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import pandas as pd

# Compute RMSE, MAE, MAPE
def calculate_metrics(y_true, y_pred):
    rmse = mean_squared_error(y_true, y_pred, squared=False)  # RMSE
    mae = mean_absolute_error(y_true, y_pred)  # MAE
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100  # MAPE (%)
    return rmse, mae, mape

# Train and Test metrics
rmse_train, mae_train, mape_train = calculate_metrics(y_train, y_train_pred)
rmse_test, mae_test, mape_test = calculate_metrics(y_test, y_test_pred)

# Create a results table
metrics_table = pd.DataFrame({
    "Metric": ["RMSE", "MAE", "MAPE (%)"],
    "Train": [rmse_train, mae_train, mape_train],
    "Test": [rmse_test, mae_test, mape_test]
})

# Print table
print(metrics_table.to_string(index=False))
# Out:
#   Metric    Train     Test
#     RMSE 3.292041 5.843083
#      MAE 2.026065 4.554980
# MAPE (%) 2.093006 4.665432
# /usr/lib/python3/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /usr/lib/python3/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define models
models = ['XGBoost', 'Support Vector Regression', 'Random Forest']

# Define R² values for Train and Test (EDIT THESE VALUES)
r2_train = [0.92, 0.89, 0.91]  # Replace with actual values
r2_test = [0.88, 0.85, 0.87]  # Replace with actual values

# Bar width
bar_height = 0.4
y_positions = np.arange(len(models))  # Model positions

# Create figure and axis
fig, ax = plt.subplots(figsize=(7, 4))

# Plot Train bars (light gray)
ax.barh(y_positions, r2_train, height=bar_height, color='lightgray', label='Train', edgecolor='black')

# Plot Test bars (black) **on top of** Train bars
ax.barh(y_positions, r2_test, height=bar_height, color='black', label='Test', edgecolor='black')

# Set labels
ax.set_xlabel(r'Coefficient of Determination (R$^2$)', fontsize=12, fontweight='bold')
ax.set_yticks(y_positions)
ax.set_yticklabels(models, fontsize=12, fontweight='bold')

# Add legend (Train & Test)
ax.legend(loc='upper right', fontsize=10, frameon=False)

# Invert y-axis to match reference image
ax.invert_yaxis()

# Grid and border styling
ax.grid(False)  # Remove grid lines
for spine in ax.spines.values():
    spine.set_linewidth(1.2)  # Thicker border

# Adjust layout
plt.tight_layout()


plt.savefig('compare.jpg')

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor  # Example model
from sklearn.datasets import make_regression

# Generate synthetic data (replace with your real dataset)
# X, y = make_regression(n_samples=200, n_features=10, noise=0.1, random_state=42)

# Define the model
model = my_model

# Perform 5-fold cross-validation
cv_scores = cross_val_score(model, X, y, cv=5, scoring='r2')

# Print results
print("Cross-validation R² scores:", cv_scores)
print("Mean R²:", cv_scores.mean())
print("Standard Deviation of R²:", cv_scores.std())
# Out:
# Cross-validation R² scores: [-0.15867841  0.32421176 -0.47240027  0.29881549  0.38224574]
# Mean R²: 0.07483886319492203
# Standard Deviation of R²: 0.3349185992959564

# %%
import pandas as pd

# Create DataFrames for train and test sets
df_train = pd.DataFrame({'y_train_actual': y_train, 'y_train_predicted': y_train_pred})
df_test = pd.DataFrame({'y_test_actual': y_test, 'y_test_predicted': y_test_pred})

# Save both in separate sheets
with pd.ExcelWriter("model_predictions.xlsx") as writer:
    df_train.to_excel(writer, sheet_name="Train", index=False)
    df_test.to_excel(writer, sheet_name="Test", index=False)

print("Excel file saved with separate sheets for train and test!")
# Out:
# Excel file saved with separate sheets for train and test!
